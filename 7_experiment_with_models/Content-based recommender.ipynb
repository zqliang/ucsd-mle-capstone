# %% [markdown]
# # Cosine TF-IDF (Term Frequency-Inverse Document Frequency) similarity

# %% [markdown]
# TF-IDF is measure of how frequent a term appears in a text and how frequent the term appears across the collection of documents.
#
# The TF-IDF score multiplies TF x IDF values. A higher score means the term is more significant.
#
# After calculating the TF-IDF score, we take the cosine of the angle between the sentences and the terms.

# %%
import pandas as pd
import numpy as np

df_anime = pd.read_csv('../data/anime-dataset-2023.csv')
df_anime['Synopsis'].head()
# Out:
# 0    Crime is timeless. By the year 2071, humanity ...
# 1    Another day, another bounty—such is the life o...
# 2    Vash the Stampede is the man with a $$60,000,0...
# 3    Robin Sena is a powerful craft user drafted in...
# 4    It is the dark century and the people are suff...
# Name: Synopsis, dtype: object

# %%
#create the tf-idf matrix for text comparison
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df_anime['Synopsis'])

# %%
# Compute cosine similarity between all anime synopsis
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(tfidf_matrix)
similarity_df = pd.DataFrame(similarity, 
                             index=df_anime['Name'], 
                             columns=df_anime['Name'])
similarity_df.head(10)
# Out:
# Name                             Cowboy Bebop  \
# Name
# Cowboy Bebop                         1.000000
# Cowboy Bebop: Tengoku no Tobira      0.265262
# Trigun                               0.020053
# Witch Hunter Robin                   0.040867
# Bouken Ou Beet                       0.001554
# Eyeshield 21                         0.017027
# Hachimitsu to Clover                 0.000000
# Hungry Heart: Wild Striker           0.005313
# Initial D Fourth Stage               0.000000
# Monster                              0.009678
#
# Name                             Cowboy Bebop: Tengoku no Tobira    Trigun  \
# Name
# Cowboy Bebop                                            0.265262  0.020053
# Cowboy Bebop: Tengoku no Tobira                         1.000000  0.038163
# Trigun                                                  0.038163  1.000000
# Witch Hunter Robin                                      0.016617  0.005122
# Bouken Ou Beet                                          0.004106  0.012405
# Eyeshield 21                                            0.022083  0.008910
# Hachimitsu to Clover                                    0.011153  0.003156
# Hungry Heart: Wild Striker                              0.012127  0.000000
# Initial D Fourth Stage                                  0.008221  0.000000
# Monster                                                 0.013432  0.023464
#
# Name                             Witch Hunter Robin  Bouken Ou Beet  \
# Name
# Cowboy Bebop                               0.040867        0.001554
# Cowboy Bebop: Tengoku no Tobira            0.016617        0.004106
# Trigun                                     0.005122        0.012405
# Witch Hunter Robin                         1.000000        0.014875
# Bouken Ou Beet                             0.014875        1.000000
# Eyeshield 21                               0.121858        0.056452
# Hachimitsu to Clover                       0.000000        0.001965
# Hungry Heart: Wild Striker                 0.014676        0.000000
# Initial D Fourth Stage                     0.008000        0.000000
# Monster                                    0.000000        0.009695
#
# Name                             Eyeshield 21  Hachimitsu to Clover  \
# Name
# Cowboy Bebop                         0.017027              0.000000
# Cowboy Bebop: Tengoku no Tobira      0.022083              0.011153
# Trigun                               0.008910              0.003156
# Witch Hunter Robin                   0.121858              0.000000
# Bouken Ou Beet                       0.056452              0.001965
# Eyeshield 21                         1.000000              0.010987
# Hachimitsu to Clover                 0.010987              1.000000
# Hungry Heart: Wild Striker           0.013827              0.000000
# Initial D Fourth Stage               0.017035              0.025009
# Monster                              0.011004              0.000000
#
# Name                             Hungry Heart: Wild Striker  \
# Name
# Cowboy Bebop                                       0.005313
# Cowboy Bebop: Tengoku no Tobira                    0.012127
# Trigun                                             0.000000
# Witch Hunter Robin                                 0.014676
# Bouken Ou Beet                                     0.000000
# Eyeshield 21                                       0.013827
# Hachimitsu to Clover                               0.000000
# Hungry Heart: Wild Striker                         1.000000
# Initial D Fourth Stage                             0.026522
# Monster                                            0.000000
#
# Name                             Initial D Fourth Stage   Monster  ...  \
# Name                                                               ...
# Cowboy Bebop                                   0.000000  0.009678  ...
# Cowboy Bebop: Tengoku no Tobira                0.008221  0.013432  ...
# Trigun                                         0.000000  0.023464  ...
# Witch Hunter Robin                             0.008000  0.000000  ...
# Bouken Ou Beet                                 0.000000  0.009695  ...
# Eyeshield 21                                   0.017035  0.011004  ...
# Hachimitsu to Clover                           0.025009  0.000000  ...
# Hungry Heart: Wild Striker                     0.026522  0.000000  ...
# Initial D Fourth Stage                         1.000000  0.000000  ...
# Monster                                        0.000000  1.000000  ...
#
# Name                             Die, Please!  Miru  \
# Name
# Cowboy Bebop                         0.000000   0.0
# Cowboy Bebop: Tengoku no Tobira      0.000000   0.0
# Trigun                               0.008295   0.0
# Witch Hunter Robin                   0.003352   0.0
# Bouken Ou Beet                       0.000000   0.0
# Eyeshield 21                         0.007967   0.0
# Hachimitsu to Clover                 0.000000   0.0
# Hungry Heart: Wild Striker           0.020025   0.0
# Initial D Fourth Stage               0.016066   0.0
# Monster                              0.016370   0.0
#
# Name                             Wo Mengjian ni Mengjian wo  Thailand  Energy  \
# Name
# Cowboy Bebop                                            0.0       0.0     0.0
# Cowboy Bebop: Tengoku no Tobira                         0.0       0.0     0.0
# Trigun                                                  0.0       0.0     0.0
# Witch Hunter Robin                                      0.0       0.0     0.0
# Bouken Ou Beet                                          0.0       0.0     0.0
# Eyeshield 21                                            0.0       0.0     0.0
# Hachimitsu to Clover                                    0.0       0.0     0.0
# Hungry Heart: Wild Striker                              0.0       0.0     0.0
# Initial D Fourth Stage                                  0.0       0.0     0.0
# Monster                                                 0.0       0.0     0.0
#
# Name                             Wu Nao Monu  Bu Xing Si: Yuan Qi  \
# Name
# Cowboy Bebop                             0.0                  0.0
# Cowboy Bebop: Tengoku no Tobira          0.0                  0.0
# Trigun                                   0.0                  0.0
# Witch Hunter Robin                       0.0                  0.0
# Bouken Ou Beet                           0.0                  0.0
# Eyeshield 21                             0.0                  0.0
# Hachimitsu to Clover                     0.0                  0.0
# Hungry Heart: Wild Striker               0.0                  0.0
# Initial D Fourth Stage                   0.0                  0.0
# Monster                                  0.0                  0.0
#
# Name                             Di Yi Xulie  Bokura no Saishuu Sensou  \
# Name
# Cowboy Bebop                             0.0                       0.0
# Cowboy Bebop: Tengoku no Tobira          0.0                       0.0
# Trigun                                   0.0                       0.0
# Witch Hunter Robin                       0.0                       0.0
# Bouken Ou Beet                           0.0                       0.0
# Eyeshield 21                             0.0                       0.0
# Hachimitsu to Clover                     0.0                       0.0
# Hungry Heart: Wild Striker               0.0                       0.0
# Initial D Fourth Stage                   0.0                       0.0
# Monster                                  0.0                       0.0
#
# Name                             Shijuuku Nichi
# Name
# Cowboy Bebop                                0.0
# Cowboy Bebop: Tengoku no Tobira             0.0
# Trigun                                      0.0
# Witch Hunter Robin                          0.0
# Bouken Ou Beet                              0.0
# Eyeshield 21                                0.0
# Hachimitsu to Clover                        0.0
# Hungry Heart: Wild Striker                  0.0
# Initial D Fourth Stage                      0.0
# Monster                                     0.0
#
# [10 rows x 24905 columns]

# %%
# anime list 
anime_list = similarity_df.columns.values


# sample anime
anime = 'InuYasha'

# top recommendation movie count
top_n = 10

# get anime similarity records
anime_sim = similarity_df[similarity_df.index == anime].values[0]

# get animes sorted by similarity
sorted_anime_ids = np.argsort(anime_sim)[::-1]

# get recommended anime names
recommended_anime = anime_list[sorted_anime_ids[1:top_n+1]]

print('\n\nTop Recommended Anime for:', anime, 'are:-\n', recommended_anime)
# Out:
# Top Recommended Anime for: InuYasha are:-
#  ['InuYasha Movie 1: Toki wo Koeru Omoi' 'InuYasha: Kanketsu-hen'
#  'Shounen Sunday CM: InuYasha-hen' 'InuYasha Movie 3: Tenka Hadou no Ken'
#  'InuYasha Movie 4: Guren no Houraijima' 'InuYasha: Kuroi Tessaiga'
#  'Kiratto Pri☆chan Season 2' 'Jewelpet Twinkle☆'
#  'InuYasha Movie 2: Kagami no Naka no Mugenjo'
#  'Shounen Sunday CM: Kyoukai no Rinne']

# %%
def content_anime_recommender(
    input_anime, similarity_database=similarity_df, anime_database_list=anime_list, top_n=10):
    
    # get anime similarity records
    anime_sim = similarity_database[similarity_database.index == input_anime].values[0]
    
    # get anime sorted by similarity
    sorted_anime_ids = np.argsort(anime_sim)[::-1]
    
    # get recommended anime names
    recommended_anime = anime_database_list[sorted_anime_ids[1:top_n+1]]
    
    print('\n\nTop Recommended Anime for:', input_anime, 'are:-\n', recommended_anime)

sample_anime = ['Death Note', 'Cowboy Bebop', 'Bleach', 
                 'Fruits Basket', 'Monster']
                 
for i in sample_anime:
    content_anime_recommender(i)
# Out:
# Top Recommended Anime for: Death Note are:-
#  ['Death Note: Rewrite' 'Mugen no Hi' 'Sekaikei Sekai Ron' 'gdMen'
#  'WONDER LiGHT' 'JK to Ero Giin Sensei' 'Dia Horizon (Kabu)'
#  'Ore no Nounai Sentakushi ga, Gakuen Love Comedy wo Zenryoku de Jama Shiteiru OVA'
#  'JK to Ero Konbini Tenchou' 'Ji Jia Shou Shen: Baolie Feiche']
#
#
# Top Recommended Anime for: Cowboy Bebop are:-
#  ['Cowboy Bebop: Tengoku no Tobira' 'Cowboy Bebop: Ein no Natsuyasumi'
#  'Saru Getchu Movie: Ougon no Pipo Helmet - Ukki Battle'
#  'Kurogane Communication' 'Kandagawa Jet Girls Recap'
#  'Kandagawa Jet Girls' 'Phantasy Star Online 2: Episode Oracle'
#  'Umeboshi Denka' 'Bounty Hunter: The Hard'
#  'Saraba Uchuu Senkan Yamato: Ai no Senshi-tachi']
#
#
# Top Recommended Anime for: Bleach are:-
#  ['Bleach: Sennen Kessen-hen'
#  'Bleach Movie 3: Fade to Black - Kimi no Na wo Yobu'
#  'Bleach Movie 1: Memories of Nobody' 'Bleach Movie 4: Jigoku-hen'
#  'Yume-iro Pâtissière SP Professional' 'Tokyo Mew Mew New ♡'
#  'Aikatsu! Movie' 'Tokyo Mew Mew' 'Bleach: The Sealed Sword Frenzy'
#  'Bleach: Memories in the Rain']
#
#
# Top Recommended Anime for: Fruits Basket are:-
#  ['Fruits Basket 1st Season' 'Fruits Basket 2nd Season'
#  'Yubisaki kara Honki no Netsujou: Osananajimi wa Shouboushi'
#  'Fruits Basket: The Final' 'Kobayashi-san Chi no Maid Dragon' 'A-Channel'
#  'Shining Tears X Wind' 'Shokugeki no Souma: San no Sara'
#  'Kobayashi-san Chi no Maid Dragon S'
#  'Kobayashi-san Chi no Maid Dragon: Valentine, Soshite Onsen! - Amari Kitai Shinaide Kudasai']
#
#
# Top Recommended Anime for: Monster are:-
#  ['Tetsuwan Atom: Atom Tanjou no Himitsu' 'Dr. Stone: New World Part 2'
#  'Inazuma Eleven Go: Chrono Stone'
#  'Saint Seiya: The Lost Canvas - Meiou Shinwa' 'Jetter Mars'
#  'Tezuka Osamu ga Kieta?! 20 Seiki Saigo no Kaijiken' 'School Rumble'
#  'Doctor Chichibuyama' 'Chijoku Shinsatsushitsu' 'Shikkaku Ishi']

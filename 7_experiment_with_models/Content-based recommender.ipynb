# %% [markdown]
# # Cosine TF-IDF (Term Frequency-Inverse Document Frequency) similarity

# %% [markdown]
# TF-IDF is measure of how frequent a term appears in a text and how frequent the term appears across the collection of documents.
#
# The TF-IDF score multiplies TF x IDF values. A higher score means the term is more significant.
#
# After calculating the TF-IDF score, we take the cosine of the angle between the sentences and the terms.

# %%
import pandas as pd
import numpy as np

df_anime = pd.read_csv('../data/anime-dataset-2023.csv')
df_anime.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3  Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4  It is the dark century and the people are suff...     TV     52.0
#
#                           Aired  ...         Studios    Source       Duration  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...         Sunrise  Original  24 min per ep
# 1                   Sep 1, 2001  ...           Bones  Original    1 hr 55 min
# 2   Apr 1, 1998 to Sep 30, 1998  ...        Madhouse     Manga  24 min per ep
# 3   Jul 3, 2002 to Dec 25, 2002  ...         Sunrise  Original  25 min per ep
# 4  Sep 30, 2004 to Sep 29, 2005  ...  Toei Animation     Manga  23 min per ep
#
#                            Rating    Rank Popularity Favorites Scored By  \
# 0  R - 17+ (violence & profanity)    41.0         43     78525  914193.0
# 1  R - 17+ (violence & profanity)   189.0        602      1448  206248.0
# 2       PG-13 - Teens 13 or older   328.0        246     15035  356739.0
# 3       PG-13 - Teens 13 or older  2764.0       1795       613   42829.0
# 4                   PG - Children  4240.0       5126        14    6413.0
#
#    Members                                          Image URL
# 0  1771505  https://cdn.myanimelist.net/images/anime/4/196...
# 1   360978  https://cdn.myanimelist.net/images/anime/1439/...
# 2   727252  https://cdn.myanimelist.net/images/anime/7/203...
# 3   111931  https://cdn.myanimelist.net/images/anime/10/19...
# 4    15001  https://cdn.myanimelist.net/images/anime/7/215...
#
# [5 rows x 24 columns]

# %%
df_anime.shape
# Out:
# (24905, 24)

# %%
#basic filtering for duplicates

duplicates_all = df_anime[df_anime.duplicated()]
print("All Duplicates:")
print(len(duplicates_all))

duplicates = df_anime[df_anime.duplicated(['Name'])].sort_values(by='Name')
print("Duplicates based on Name:")
print(len(duplicates))
duplicates = duplicates[['anime_id', 'Name']]
print(duplicates)

df_anime_new = df_anime.drop_duplicates(['Name'])
print("Cleaned anime shape: {} \n".format(df_anime_new.shape))
print("Old anime shape: {}".format(df_anime.shape))
# Out:
# All Duplicates:
# 0
# Duplicates based on Name:
# 4
#        anime_id       Name
# 24840     55658  Awakening
# 24586     55351  Azur Lane
# 24807     55610   Souseiki
# 24781     55582     Utopia
# Cleaned anime shape: (24901, 24)
#
# Old anime shape: (24905, 24)

# %%
#filter out certain genre
to_exclude = df_anime[df_anime['Genres'].str.contains('Hentai', case=False, na=False)]
filtered_df = df_anime[~df_anime.index.isin(to_exclude.index)]
filtered_df.shape
# Out:
# (23419, 24)

# %%
# Convert Name column to lowercase and remove spaces
filtered_df['Processed_Name'] = filtered_df['Name'].str.lower().replace(' ', '')

# Filter out rows with titles in lowercase and without spaces
duplicate_rows = filtered_df[filtered_df.duplicated(subset='Processed_Name', keep=False) | ~filtered_df.duplicated(subset='Processed_Name', keep=False) & ~filtered_df['Processed_Name'].str.contains(' ')]

print(duplicate_rows)
# Filter out rows that are upper case and have no spacing, e.g. between Death Note and DEATHNOTE, keep Death Note
filtered_df = filtered_df[~((filtered_df['Processed_Name'].isin(duplicate_rows['Processed_Name'])) & (filtered_df.duplicated(subset='Processed_Name', keep=False)))]

# Drop the intermediate 'Processed_Name' column
filtered_df = filtered_df.drop(columns='Processed_Name')

filtered_df.shape
# Out:
#        anime_id         Name English name   Other name    Score  \
# 2             6       Trigun       Trigun        トライガン     8.22
# 9            19      Monster      Monster        モンスター     8.87
# 10           20       Naruto       Naruto          ナルト     7.99
# 15           25    Sunabouzu  Desert Punk         砂ぼうず     7.38
# 16           26   Texhnolyze   Texhnolyze   TEXHNOLYZE     7.76
# ...         ...          ...          ...          ...      ...
# 24880     55707       Kokoro      UNKNOWN            心  UNKNOWN
# 24885     55716  Mechronicle  Mechronicle  Mechronicle  UNKNOWN
# 24896     55727         Miru      UNKNOWN           未ル  UNKNOWN
# 24898     55729     Thailand      UNKNOWN     Thailand  UNKNOWN
# 24899     55730       Energy      UNKNOWN       Energy  UNKNOWN
#
#                                          Genres  \
# 2                     Action, Adventure, Sci-Fi
# 9                      Drama, Mystery, Suspense
# 10                   Action, Adventure, Fantasy
# 15     Action, Adventure, Comedy, Sci-Fi, Ecchi
# 16                        Action, Drama, Sci-Fi
# ...                                         ...
# 24880                                   UNKNOWN
# 24885                                   UNKNOWN
# 24896                                    Action
# 24898                               Avant Garde
# 24899                               Avant Garde
#
#                                                 Synopsis     Type Episodes  \
# 2      Vash the Stampede is the man with a $$60,000,0...       TV     26.0
# 9      Dr. Kenzou Tenma, an elite neurosurgeon recent...       TV     74.0
# 10     Moments prior to Naruto Uzumaki's birth, a hug...       TV    220.0
# 15     The Great Kanto Desert, a sweltering wasteland...       TV     24.0
# 16     In the dark underground city of Lux, people li...       TV     22.0
# ...                                                  ...      ...      ...
# 24880      Music video for the song Kokoro by Shikidrop.    Music      1.0
# 24885  Set in a mechanical world, Mechronicle tells t...  UNKNOWN  UNKNOWN
# 24896           No description available for this anime.  UNKNOWN  UNKNOWN
# 24898       Music video for the song Thailand by Oh Shu.    Music      1.0
# 24899  Music video for the song Energy by SLEEQ (Kim ...    Music      1.0
#
#                               Aired  ...    Source       Duration  \
# 2       Apr 1, 1998 to Sep 30, 1998  ...     Manga  24 min per ep
# 9       Apr 7, 2004 to Sep 28, 2005  ...     Manga  24 min per ep
# 10       Oct 3, 2002 to Feb 8, 2007  ...     Manga  23 min per ep
# 15      Oct 6, 2004 to Mar 30, 2005  ...     Manga  24 min per ep
# 16     Apr 17, 2003 to Sep 25, 2003  ...  Original  23 min per ep
# ...                             ...  ...       ...            ...
# 24880                  Jul 30, 2020  ...  Original          4 min
# 24885                 Not available  ...  Original        Unknown
# 24896                     2024 to ?  ...  Original        Unknown
# 24898                   Jul 3, 2014  ...  Original          4 min
# 24899                  Feb 11, 2015  ...  Original          4 min
#
#                                Rating     Rank Popularity Favorites  \
# 2           PG-13 - Teens 13 or older    328.0        246     15035
# 9                    R+ - Mild Nudity     26.0        142     47235
# 10          PG-13 - Teens 13 or older    599.0          8     76343
# 15     R - 17+ (violence & profanity)   2167.0       1546       822
# 16                   R+ - Mild Nudity    990.0        935      4786
# ...                               ...      ...        ...       ...
# 24880       PG-13 - Teens 13 or older  UNKNOWN      24664         0
# 24885                         UNKNOWN      0.0          0         0
# 24896                         UNKNOWN      0.0          0         0
# 24898       PG-13 - Teens 13 or older      0.0          0         0
# 24899       PG-13 - Teens 13 or older      0.0          0         0
#
#        Scored By  Members                                          Image URL  \
# 2       356739.0   727252  https://cdn.myanimelist.net/images/anime/7/203...
# 9       368569.0  1013100  https://cdn.myanimelist.net/images/anime/10/18...
# 10     1883772.0  2717330  https://cdn.myanimelist.net/images/anime/13/17...
# 15       53709.0   134894  https://cdn.myanimelist.net/images/anime/6/755...
# 16       54857.0   239423  https://cdn.myanimelist.net/images/anime/1027/...
# ...          ...      ...                                                ...
# 24880    UNKNOWN       31  https://cdn.myanimelist.net/images/anime/1146/...
# 24885    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1074/...
# 24896    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1135/...
# 24898    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1887/...
# 24899    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1817/...
#
#        Processed_Name
# 2              trigun
# 9             monster
# 10             naruto
# 15          sunabouzu
# 16         texhnolyze
# ...               ...
# 24880          kokoro
# 24885     mechronicle
# 24896            miru
# 24898        thailand
# 24899          energy
#
# [2278 rows x 25 columns]
# /var/folders/5c/vmwbxs651m7d5qzp8tkc7v8m0000gn/T/ipykernel_1353/2288150537.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Processed_Name'] = filtered_df['Name'].str.lower().replace(' ', '')
# (23409, 24)

# %%
#drop rows with unknown genres
unknown_rows = filtered_df[filtered_df['Genres'].str.lower() == 'unknown']
filtered_df = filtered_df.drop(unknown_rows.index)
filtered_df.shape
# Out:
# (18486, 24)

# %%
#create the tf-idf matrix for text comparison
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
synopsis_vectors = tfidf.fit_transform(filtered_df['Synopsis'])

# %%
#use one-hot encoder to include genre in the recommendation
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import hstack

encoder = OneHotEncoder(sparse_output=True)

genre_encoded_sparse = encoder.fit_transform(filtered_df[['Genres']].explode('Genres'))

# Step 4: Combine the sparse matrices horizontally (hstack)
combined_sparse_matrix = hstack([genre_encoded_sparse, synopsis_vectors])

# Display the combined sparse matrix
print("Combined Sparse Matrix:")
print(combined_sparse_matrix)
# Out:
# Combined Sparse Matrix:
#   (0, 143)	1.0
#   (0, 45812)	0.09473567569169065
#   (0, 29905)	0.046649780496261554
#   (0, 34817)	0.06916315278280448
#   (0, 13839)	0.04756548741308503
#   (0, 28857)	0.07186902036053307
#   (0, 24299)	0.03791912201838669
#   (0, 7738)	0.07847762250313407
#   (0, 43985)	0.0776244204124312
#   (0, 8939)	0.06131487428208387
#   (0, 31949)	0.06750986660476928
#   (0, 25450)	0.11188802075966059
#   (0, 35130)	0.0660591887632018
#   (0, 26303)	0.0865188371789169
#   (0, 11245)	0.0922307348253924
#   (0, 24530)	0.04820859517965824
#   (0, 9402)	0.0675802192870711
#   (0, 7022)	0.06696158890308303
#   (0, 8356)	0.0793970282294058
#   (0, 7064)	0.07270862016382937
#   (0, 45762)	0.06226719863292278
#   (0, 5866)	0.0793970282294058
#   (0, 10777)	0.08243096281688525
#   (0, 9089)	0.11188802075966059
#   (0, 45396)	0.12010485927243436
#   :	:
#   (18481, 29771)	0.4587973646408326
#   (18481, 38903)	0.28961719018115994
#   (18481, 27978)	0.266399545908467
#   (18481, 44692)	0.2583515644523988
#   (18482, 494)	1.0
#   (18482, 35644)	0.48231210772650307
#   (18482, 38561)	0.48231210772650307
#   (18482, 18974)	0.44931526874803385
#   (18482, 22433)	0.3703763559632167
#   (18482, 38903)	0.2159793638284476
#   (18482, 27978)	0.19866501851463952
#   (18482, 12772)	0.2691712827138955
#   (18482, 44692)	0.19266331014264174
#   (18483, 694)	1.0
#   (18483, 10627)	0.6034963364251288
#   (18483, 3160)	0.525089070759619
#   (18483, 4356)	0.600061363270664
#   (18484, 80)	1.0
#   (18484, 10627)	0.6034963364251288
#   (18484, 3160)	0.525089070759619
#   (18484, 4356)	0.600061363270664
#   (18485, 95)	1.0
#   (18485, 10627)	0.6034963364251288
#   (18485, 3160)	0.525089070759619
#   (18485, 4356)	0.600061363270664

# %%
# Compute cosine similarity between all anime synopsis
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(combined_sparse_matrix)
similarity_df = pd.DataFrame(similarity, 
                             index=filtered_df['Name'], 
                             columns=filtered_df['Name'])
similarity_df.head(10)
# Out:
# Name                             Cowboy Bebop  \
# Name
# Cowboy Bebop                         1.000000
# Cowboy Bebop: Tengoku no Tobira      0.131838
# Trigun                               0.009761
# Witch Hunter Robin                   0.020287
# Bouken Ou Beet                       0.000739
# Eyeshield 21                         0.008328
# Hachimitsu to Clover                 0.000000
# Hungry Heart: Wild Striker           0.002539
# Initial D Fourth Stage               0.000000
# Monster                              0.004654
#
# Name                             Cowboy Bebop: Tengoku no Tobira    Trigun  \
# Name
# Cowboy Bebop                                            0.131838  0.009761
# Cowboy Bebop: Tengoku no Tobira                         1.000000  0.018745
# Trigun                                                  0.018745  1.000000
# Witch Hunter Robin                                      0.008214  0.002533
# Bouken Ou Beet                                          0.001993  0.006092
# Eyeshield 21                                            0.010943  0.004248
# Hachimitsu to Clover                                    0.005514  0.001544
# Hungry Heart: Wild Striker                              0.005794  0.000000
# Initial D Fourth Stage                                  0.003878  0.000000
# Monster                                                 0.006492  0.011393
#
# Name                             Witch Hunter Robin  Bouken Ou Beet  \
# Name
# Cowboy Bebop                               0.020287        0.000739
# Cowboy Bebop: Tengoku no Tobira            0.008214        0.001993
# Trigun                                     0.002533        0.006092
# Witch Hunter Robin                         1.000000        0.007225
# Bouken Ou Beet                             0.007225        1.000000
# Eyeshield 21                               0.062500        0.027794
# Hachimitsu to Clover                       0.000000        0.000975
# Hungry Heart: Wild Striker                 0.007323        0.000000
# Initial D Fourth Stage                     0.003793        0.000000
# Monster                                    0.000000        0.004680
#
# Name                             Eyeshield 21  Hachimitsu to Clover  \
# Name
# Cowboy Bebop                         0.008328              0.000000
# Cowboy Bebop: Tengoku no Tobira      0.010943              0.005514
# Trigun                               0.004248              0.001544
# Witch Hunter Robin                   0.062500              0.000000
# Bouken Ou Beet                       0.027794              0.000975
# Eyeshield 21                         1.000000              0.005568
# Hachimitsu to Clover                 0.005568              1.000000
# Hungry Heart: Wild Striker           0.006610              0.000000
# Initial D Fourth Stage               0.008325              0.013220
# Monster                              0.005274              0.000000
#
# Name                             Hungry Heart: Wild Striker  \
# Name
# Cowboy Bebop                                       0.002539
# Cowboy Bebop: Tengoku no Tobira                    0.005794
# Trigun                                             0.000000
# Witch Hunter Robin                                 0.007323
# Bouken Ou Beet                                     0.000000
# Eyeshield 21                                       0.006610
# Hachimitsu to Clover                               0.000000
# Hungry Heart: Wild Striker                         1.000000
# Initial D Fourth Stage                             0.012669
# Monster                                            0.000000
#
# Name                             Initial D Fourth Stage   Monster  ...  \
# Name                                                               ...
# Cowboy Bebop                                   0.000000  0.004654  ...
# Cowboy Bebop: Tengoku no Tobira                0.003878  0.006492  ...
# Trigun                                         0.000000  0.011393  ...
# Witch Hunter Robin                             0.003793  0.000000  ...
# Bouken Ou Beet                                 0.000000  0.004680  ...
# Eyeshield 21                                   0.008325  0.005274  ...
# Hachimitsu to Clover                           0.013220  0.000000  ...
# Hungry Heart: Wild Striker                     0.012669  0.000000  ...
# Initial D Fourth Stage                         1.000000  0.000000  ...
# Monster                                        0.000000  1.000000  ...
#
# Name                             Beauty and the Brawn  4 Week Lovers  \
# Name
# Cowboy Bebop                                 0.000000       0.006794
# Cowboy Bebop: Tengoku no Tobira              0.000000       0.001752
# Trigun                                       0.000000       0.011806
# Witch Hunter Robin                           0.000873       0.001310
# Bouken Ou Beet                               0.000000       0.001417
# Eyeshield 21                                 0.001224       0.014114
# Hachimitsu to Clover                         0.003132       0.008780
# Hungry Heart: Wild Striker                   0.000000       0.003845
# Initial D Fourth Stage                       0.000000       0.002094
# Monster                                      0.000000       0.005189
#
# Name                             Die, Please!  Miru  \
# Name
# Cowboy Bebop                         0.000000   0.0
# Cowboy Bebop: Tengoku no Tobira      0.000000   0.0
# Trigun                               0.004140   0.0
# Witch Hunter Robin                   0.001606   0.0
# Bouken Ou Beet                       0.000000   0.0
# Eyeshield 21                         0.003916   0.0
# Hachimitsu to Clover                 0.000000   0.0
# Hungry Heart: Wild Striker           0.010099   0.0
# Initial D Fourth Stage               0.007876   0.0
# Monster                              0.008227   0.0
#
# Name                             Wo Mengjian ni Mengjian wo  Thailand  Energy  \
# Name
# Cowboy Bebop                                            0.0       0.0     0.0
# Cowboy Bebop: Tengoku no Tobira                         0.0       0.0     0.0
# Trigun                                                  0.0       0.0     0.0
# Witch Hunter Robin                                      0.0       0.0     0.0
# Bouken Ou Beet                                          0.0       0.0     0.0
# Eyeshield 21                                            0.0       0.0     0.0
# Hachimitsu to Clover                                    0.0       0.0     0.0
# Hungry Heart: Wild Striker                              0.0       0.0     0.0
# Initial D Fourth Stage                                  0.0       0.0     0.0
# Monster                                                 0.0       0.0     0.0
#
# Name                             Wu Nao Monu  Bu Xing Si: Yuan Qi  Di Yi Xulie
# Name
# Cowboy Bebop                             0.0                  0.0          0.0
# Cowboy Bebop: Tengoku no Tobira          0.0                  0.0          0.0
# Trigun                                   0.0                  0.0          0.0
# Witch Hunter Robin                       0.0                  0.0          0.0
# Bouken Ou Beet                           0.0                  0.0          0.0
# Eyeshield 21                             0.0                  0.0          0.0
# Hachimitsu to Clover                     0.0                  0.0          0.0
# Hungry Heart: Wild Striker               0.0                  0.0          0.0
# Initial D Fourth Stage                   0.0                  0.0          0.0
# Monster                                  0.0                  0.0          0.0
#
# [10 rows x 18486 columns]

# %%
# anime list 
anime_list = similarity_df.columns.values


# sample anime
anime = 'Death Note'

# top recommendation movie count
top_n = 10

# get anime similarity records
anime_sim = similarity_df[similarity_df.index == anime].values[0]

# get animes sorted by similarity
sorted_anime_ids = np.argsort(anime_sim)[::-1]

# get recommended anime names
recommended_anime = anime_list[sorted_anime_ids[1:top_n+1]]

print('\n\nTop Recommended Anime for:', anime, 'are:-\n', recommended_anime)
# Out:
# Top Recommended Anime for: Death Note are:-
#  ['Death Note: Rewrite' 'Munou na Nana' 'Warau Salesman Special Program'
#  'Mugen no Hi' 'Sekaikei Sekai Ron' 'gdMen'
#  'Ore no Nounai Sentakushi ga, Gakuen Love Comedy wo Zenryoku de Jama Shiteiru OVA'
#  'Dia Horizon (Kabu)' 'Ji Jia Shou Shen: Baolie Feiche'
#  'Hikari: Be My Light']

# %%
def content_anime_recommender(
    input_anime, similarity_database=similarity_df, anime_database_list=anime_list, top_n=10):
    
    # get anime similarity records
    anime_sim = similarity_database[similarity_database.index == input_anime].values[0]
    
    # get anime sorted by similarity
    sorted_anime_ids = np.argsort(anime_sim)[::-1]
    
    # get recommended anime names
    recommended_anime = anime_database_list[sorted_anime_ids[1:top_n+1]]
    
    print('\n\nTop Recommended Anime for:', input_anime, 'are:-\n', recommended_anime)

sample_anime = ['Death Note', 'Cowboy Bebop', 'Bleach', 
                 'Fruits Basket', 'Monster']
                 
for i in sample_anime:
    content_anime_recommender(i)
# Out:
# Top Recommended Anime for: Death Note are:-
#  ['Death Note: Rewrite' 'Munou na Nana' 'Warau Salesman Special Program'
#  'Mugen no Hi' 'Sekaikei Sekai Ron' 'gdMen'
#  'Ore no Nounai Sentakushi ga, Gakuen Love Comedy wo Zenryoku de Jama Shiteiru OVA'
#  'Dia Horizon (Kabu)' 'Ji Jia Shou Shen: Baolie Feiche'
#  'Hikari: Be My Light']
#
#
# Top Recommended Anime for: Cowboy Bebop are:-
#  ['Koukaku Kidoutai: Stand Alone Complex' 'Hate no issen EPISODE ZERO'
#  'SSSS.Gridman' 'Cowboy Bebop: Tengoku no Tobira'
#  'Cowboy Bebop: Ein no Natsuyasumi'
#  'Saru Getchu Movie: Ougon no Pipo Helmet - Ukki Battle'
#  'Kurogane Communication' 'Kandagawa Jet Girls Recap' 'Umeboshi Denka'
#  'Phantasy Star Online 2: Episode Oracle']
#
#
# Top Recommended Anime for: Bleach are:-
#  ['Bleach: Sennen Kessen-hen'
#  'Bleach Movie 3: Fade to Black - Kimi no Na wo Yobu'
#  'Bleach Movie 1: Memories of Nobody' 'Bleach Movie 4: Jigoku-hen'
#  'Bleach: The Sealed Sword Frenzy'
#  'Bleach Movie 2: The DiamondDust Rebellion - Mou Hitotsu no Hyourinmaru'
#  'Yuan Long' 'Wu Ying Sanqian Dao' 'Sword Art Online: Alicization'
#  'Bai Lian Cheng Shen']
#
#
# Top Recommended Anime for: Fruits Basket are:-
#  ['Fruits Basket 1st Season' 'Fruits Basket 2nd Season'
#  'Fruits Basket: The Final' 'Mizuiro (2003)' 'Kanon' 'Air'
#  'Clannad: After Story' 'Wind: A Breath of Heart (TV)'
#  'Kokoro Connect: Michi Random' 'Sora no Aosa wo Shiru Hito yo']
#
#
# Top Recommended Anime for: Monster are:-
#  ['Black Jack' 'Monster Special Edition' 'Shion no Ou'
#  'Sakurako-san no Ashimoto ni wa Shitai ga Umatteiru'
#  'Monster Extra: Hottan' 'Tetsuwan Atom: Atom Tanjou no Himitsu'
#  'Dr. Stone: New World Part 2' 'Inazuma Eleven Go: Chrono Stone'
#  'Saint Seiya: The Lost Canvas - Meiou Shinwa' 'Jetter Mars']

# %%
df_users_ratings = pd.read_csv('../data/users-score-2023.csv')
df_users_ratings[df_users_ratings['Anime Title'] == 'Death Note'].head()
print(df_users_ratings.shape)
# Out:
# (24325191, 5)

# %% [markdown]
# ### Deriving ground truth using threshold-based approach

# %%
# find relevant anime for ground truth, set ratings above 7
threshold = 7

sample_size = 10000

# take sample from df_users_ratings
sample_data = df_users_ratings.sample(n=sample_size, random_state=42)  #set random_state for reproducibility

#create ground truth based on the threshold
avg_ratings = sample_data.groupby('Anime Title')['rating'].mean()
print(avg_ratings)

# Filter out titles where the average rating is greater than the threshold
liked_anime = avg_ratings[avg_ratings > threshold].index.tolist()

# group by anime and create the ground_truths dictionary
ground_truths = df_users_ratings.groupby('Anime Title')['Anime Title'].apply(lambda x: liked_anime).to_dict()


#print out the items
print (set(ground_truths))
# Out:
# Anime Title
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi     8.000000
# "Bungaku Shoujo" Movie                        7.750000
# "Oshi no Ko"                                  8.500000
# .hack//G.U. Returner                          7.000000
# .hack//G.U. Trilogy: Parody Mode              6.000000
#                                                ...
# xxxHOLiC                                      8.714286
# xxxHOLiC Movie: Manatsu no Yoru no Yume       6.833333
# xxxHOLiC Rou                                 10.000000
# xxxHOLiC Shunmuki                             7.500000
# xxxHOLiC◆Kei                                  7.333333
# Name: rating, Length: 3148, dtype: float64
# {'Glass no Kamen (2005)', 'Watashi, Nouryoku wa Heikinchi de tte Itta yo ne!', 'Eiyuu Densetsu: Head On! Master Senshi', 'Madonna (Movie)', 'Boku no Chikyuu wo Mamotte: Kiniro no Toki Nagarete', 'Musashi no Ken', 'Yoshimaho', 'Naeil-eun Pyeongbeomhae Jilgeoya', 'Teekyuu 5 Specials', 'Ikoku Meiro no Croisée Picture Drama', 'Shoutai Hanmei Nameless Girl', 'Okoshiyasu, Chitose-chan Recaps', 'Boku wa Tomodachi ga Sukunai Next', 'Shaonian Ge Xing: Feng Hua Xue Yue Pian Special', 'Kero Kero Keroppi no Dai Bouken', 'Happiness Charge Precure! Movie: Ningyou no Kuni no Ballerina', 'Candy Candy (Movie)', 'Shin Bikkuriman', 'Gegege no Kitarou (1968)', 'Animal Yokochou', 'Natsu-iro Kiseki: 15-kaime no Natsuyasumi', 'Kure-nai OVA', 'Shinken Seminar Koukou Kouza', 'Versailles no Bara to Onna-tachi', 'Ame to Cappuccino', 'Mazinger Z', 'Shingeki! Kyojin Chuugakkou', '009-1: R&B', 'Lupin III: Babylon no Ougon Densetsu', 'Detective Conan: Conan vs. Kid - Jet Black Sniper', 'Battle Royal High School', 'First Love', 'Wo Shi Jiang Xiaobai', "Fate/stay night Movie: Heaven's Feel - I. Presage Flower", 'Kuro to Kin no Akanai Kagi.', 'Osomatsu-san Short Film Series', 'Negima!?', 'Eisai Kyoiku', 'Hatsukoi Limited.: Gentei Shoujo', 'Ling Jian Zun', 'Kaze no Toori Michi', '1', 'Nils no Fushigi na Tabi', 'Kidou Senshi Gundam: Dai 08 MS Shoutai - Sanjigen to no Tatakai', 'Munou na Nana', 'Rude Lose Dance', 'Bad End', 'Mushiba Tetsudou', 'Tsuki ga Kirei', 'Toshoshitsu no Kanojo: Seiso na Kimi ga Ochiru made - The Animation', 'Taishou Yakyuu Musume. Specials', 'Momoya x Peeping Life: Go en desu yo!', 'Majime ni Fumajime Kaiketsu Zorori', 'AD Police', 'Nogsaegjeoncha Hamos', 'Eizouken ni wa Te wo Dasu na!', 'Saint Seiya: The Lost Canvas - Meiou Shinwa 2', 'Mao Zhi Ming', 'Shoujo Ramune', 'Curly', 'Grimms Notes The Animation', 'Seton Doubutsuki: Risu no Banner', 'Aria the Origination: Sono Choppiri Himitsu no Basho ni...', 'Astro Boy: Tetsuwan Atom - Getsumen Kichi - Kieta Robot no Nazo', 'Shaonian Bai Ma Zui Chun Feng', 'Go! Samurai', 'Crayon Shin-chan Movie 18: Chou Jikuu! Arashi wo Yobu Ora no Hanayome', 'Na Bbeun Sang Sa', 'Bungaku Shoujo', 'Yo! Daitouryou Trap-kun', 'Gyakusatsu Kikan', 'Mayoi Neko Overrun! Specials', 'Gebäude Bäude', 'Konjiki no Gash Bell!!: Hashire Gash!! Ubawareta Umagon', 'Kurokami: Intermission', 'Seikaisuru Kado: Ninovo', 'High School DxD BorN: Yomigaeranai Fushichou', 'Rayearth', 'Makai Toshi Shinjuku', 'Ero Manga! H mo Manga mo Step-up♪', 'Akai Kiba: Blue Sonnet', 'Onmyouji: Youen Emaki', 'Ore no Imouto ga Konnani Kawaii Wake ga Nai: SD Chara ni Yoru Character Commentary', 'Chu Feng: B.E.E', 'Kubikiri Cycle: Aoiro Savant to Zaregotozukai', 'Naruto SD: Rock Lee no Seishun Full-Power Ninden', 'Tottoko Hamtarou OVA 4: Hamuchanzu no Mezase! Hamuhamu Kin Medal - Hashire! Hashire! Daisakusen', 'Huan You Lieren', 'Mu Wang Zhi Wang: Qi Lin Jue', 'Ahoy!! Warera Houshou Kaizoku-dan☆', 'Shisha no Teikoku', 'Shounen Sunday CM: Tokiwa Kitareri!! CM', 'Aruiwa Eiga no Yona', 'Slam Dunk', 'Muramasa', 'Princess Lover!: Magical Knight Maria-chan', 'Neo Satomi Hakkenden: Satomi-chanchi no Hachi Danshi', 'Mahou no Princess Minky Momo vs. Mahou no Tenshi Creamy Mami', 'Deko Boko Friends', 'Esper Mami', 'Soshite Watashi wa Sensei ni...', 'Violet Evergarden CM', 'Kantoku Fuyuki Todoki', 'EDEN', 'Lupin III: Part III', 'Juubee Ninpuuchou', "Queen's Blade: Gyokuza wo Tsugu Mono Specials", 'Hataage! Kemono Michi', 'Lupin III 3DCG', 'Naruto', 'Shin Captain Tsubasa', 'Uchuu no Senshi', 'Zoids Wild Zero', 'Haru Dorobou', 'Cluster Edge Specials', 'Shayou (Music)', 'Shishunki Bishoujo Gattai Robo Z-Mind', 'Duel Masters Movie 1: Yami no Shiro no Maryuuou', 'Lingerie Senshi Papillon Rose', 'Gyakuten Majo Saiban: Chijo na Majo ni Sabakarechau The Animation', 'Ore no Imouto ga Konnani Kawaii Wake ga Nai.: Ore no Imouto ga Konnani Eroge na Wake Nai', 'Hakuouki: Otogisoushi Special', 'gdgd Fairies', 'Boku wa Omocha', 'Kitaku-bu Katsudou Kiroku: Miniature Theater', 'Bik ...

# %%
#precision at n: measures the proportion of relevant items among the top n
def content_anime_recommender2(
    input_anime, ground_truths, similarity_database=similarity_df, anime_database_list=anime_list, top_n=10):
    
    # get anime similarity records
    anime_sim = similarity_database[similarity_database.index == input_anime].values[0]
    
    # get anime sorted by similarity
    sorted_anime_ids = np.argsort(anime_sim)[::-1]
    
    # get recommended anime names
    recommended_anime = anime_database_list[sorted_anime_ids[1:top_n+1]]
    
    # Calculate Precision at K
    intersection = set(recommended_anime) & set(ground_truths)
    precision_at_n = len(intersection) / top_n
    rounded_precision = round(precision_at_n, 2)
    
    print('\n\nTop Recommended Anime for ', input_anime, recommended_anime)
    print('\nPrecision at', top_n, '=', rounded_precision)

sample_anime2 = ['Death Note', 'InuYasha', 'Chobits', 'Hikari: Be My Light']

for i in sample_anime2:
    content_anime_recommender2(i, ground_truths)
# Out:
# Top Recommended Anime for  Death Note ['Death Note: Rewrite' 'Munou na Nana' 'Warau Salesman Special Program'
#  'Mugen no Hi' 'Sekaikei Sekai Ron' 'gdMen'
#  'Ore no Nounai Sentakushi ga, Gakuen Love Comedy wo Zenryoku de Jama Shiteiru OVA'
#  'Dia Horizon (Kabu)' 'Ji Jia Shou Shen: Baolie Feiche'
#  'Hikari: Be My Light']
#
# Precision at 10 = 0.8
#
#
# Top Recommended Anime for  InuYasha ['InuYasha Movie 1: Toki wo Koeru Omoi' 'InuYasha: Kanketsu-hen'
#  'InuYasha Movie 3: Tenka Hadou no Ken'
#  'InuYasha Movie 4: Guren no Houraijima' 'InuYasha: Kuroi Tessaiga'
#  'InuYasha Movie 2: Kagami no Naka no Mugenjo' 'Yao Shen Ji'
#  'Doupo Cangqiong 2nd Season' 'MY WIFE IS A DEMON QUEEN' 'Seirei Gensouki']
#
# Precision at 10 = 0.9
#
#
# Top Recommended Anime for  Chobits ['Kono Minikuku mo Utsukushii Sekai' 'Chobits Recap'
#  'Mahoromatic: Motto Utsukushii Mono' 'Chobits: Chibits'
#  'Ai no Sungekijou' 'Chii-chan no Kageokuri' 'Chii-chan to Hige Ojisan'
#  'Koneko no Chi: Ponponra Dairyokou' 'Uchi no 3 Shimai'
#  'Tsurezure Children']
#
# Precision at 10 = 0.8
#
#
# Top Recommended Anime for  Hikari: Be My Light ['Osakana wa Ami no Naka' "Saezuru Tori wa Habatakanai: Don't Stay Gold"
#  'Kono Danshi, Sekka ni Nayandemasu.' "Be-Boy Kidnapp'n Idol" 'Ten Count'
#  'Yes ka No ka Hanbun ka' 'Earthian' 'Houkago no Shokuinshitsu'
#  'Zujou Kazoku Cavigliano' 'Tensei Mae no Ryouma to Tabuchi']
#
# Precision at 10 = 0.7

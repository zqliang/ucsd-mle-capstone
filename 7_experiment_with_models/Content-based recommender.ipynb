# %% [markdown]
# # Cosine TF-IDF (Term Frequency-Inverse Document Frequency) similarity

# %% [markdown]
# TF-IDF is measure of how frequent a term appears in a text and how frequent the term appears across the collection of documents.
#
# The TF-IDF score multiplies TF x IDF values. A higher score means the term is more significant.
#
# After calculating the TF-IDF score, we take the cosine of the angle between the sentences and the terms.

# %%
import pandas as pd
import numpy as np

df_anime = pd.read_csv('../data/anime-dataset-2023.csv')
df_anime.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3  Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4  It is the dark century and the people are suff...     TV     52.0
#
#                           Aired  ...         Studios    Source       Duration  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...         Sunrise  Original  24 min per ep
# 1                   Sep 1, 2001  ...           Bones  Original    1 hr 55 min
# 2   Apr 1, 1998 to Sep 30, 1998  ...        Madhouse     Manga  24 min per ep
# 3   Jul 3, 2002 to Dec 25, 2002  ...         Sunrise  Original  25 min per ep
# 4  Sep 30, 2004 to Sep 29, 2005  ...  Toei Animation     Manga  23 min per ep
#
#                            Rating    Rank Popularity Favorites Scored By  \
# 0  R - 17+ (violence & profanity)    41.0         43     78525  914193.0
# 1  R - 17+ (violence & profanity)   189.0        602      1448  206248.0
# 2       PG-13 - Teens 13 or older   328.0        246     15035  356739.0
# 3       PG-13 - Teens 13 or older  2764.0       1795       613   42829.0
# 4                   PG - Children  4240.0       5126        14    6413.0
#
#    Members                                          Image URL
# 0  1771505  https://cdn.myanimelist.net/images/anime/4/196...
# 1   360978  https://cdn.myanimelist.net/images/anime/1439/...
# 2   727252  https://cdn.myanimelist.net/images/anime/7/203...
# 3   111931  https://cdn.myanimelist.net/images/anime/10/19...
# 4    15001  https://cdn.myanimelist.net/images/anime/7/215...
#
# [5 rows x 24 columns]

# %%
df_anime.shape
# Out:
# (24905, 24)

# %%
#basic filtering for duplicates

duplicates_all = df_anime[df_anime.duplicated()]
print("All Duplicates:")
print(len(duplicates_all))

duplicates = df_anime[df_anime.duplicated(['Name'])].sort_values(by='Name')
print("Duplicates based on Name:")
print(len(duplicates))
duplicates = duplicates[['anime_id', 'Name']]
print(duplicates)

df_anime_new = df_anime.drop_duplicates(['Name'])
print("Cleaned anime shape: {} \n".format(df_anime_new.shape))
print("Old anime shape: {}".format(df_anime.shape))
# Out:
# All Duplicates:
# 0
# Duplicates based on Name:
# 4
#        anime_id       Name
# 24840     55658  Awakening
# 24586     55351  Azur Lane
# 24807     55610   Souseiki
# 24781     55582     Utopia
# Cleaned anime shape: (24901, 24)
#
# Old anime shape: (24905, 24)

# %%
#filter out certain genre
to_exclude = df_anime[df_anime['Genres'].str.contains('Hentai', case=False, na=False)]
filtered_df = df_anime[~df_anime.index.isin(to_exclude.index)]
filtered_df.shape
# Out:
# (23419, 24)

# %%
# Convert Name column to lowercase and remove spaces
filtered_df['Processed_Name'] = filtered_df['Name'].str.lower().replace(' ', '')

# Filter out rows with titles in lowercase and without spaces
duplicate_rows = filtered_df[filtered_df.duplicated(subset='Processed_Name', keep=False) | ~filtered_df.duplicated(subset='Processed_Name', keep=False) & ~filtered_df['Processed_Name'].str.contains(' ')]

print(duplicate_rows)
# Filter out rows that are upper case and have no spacing, e.g. between Death Note and DEATHNOTE, keep Death Note
filtered_df = filtered_df[~((filtered_df['Processed_Name'].isin(duplicate_rows['Processed_Name'])) & (filtered_df.duplicated(subset='Processed_Name', keep=False)))]

# Drop the intermediate 'Processed_Name' column
filtered_df = filtered_df.drop(columns='Processed_Name')

filtered_df.shape
# Out:
#        anime_id         Name English name   Other name    Score  \
# 2             6       Trigun       Trigun        トライガン     8.22
# 9            19      Monster      Monster        モンスター     8.87
# 10           20       Naruto       Naruto          ナルト     7.99
# 15           25    Sunabouzu  Desert Punk         砂ぼうず     7.38
# 16           26   Texhnolyze   Texhnolyze   TEXHNOLYZE     7.76
# ...         ...          ...          ...          ...      ...
# 24880     55707       Kokoro      UNKNOWN            心  UNKNOWN
# 24885     55716  Mechronicle  Mechronicle  Mechronicle  UNKNOWN
# 24896     55727         Miru      UNKNOWN           未ル  UNKNOWN
# 24898     55729     Thailand      UNKNOWN     Thailand  UNKNOWN
# 24899     55730       Energy      UNKNOWN       Energy  UNKNOWN
#
#                                          Genres  \
# 2                     Action, Adventure, Sci-Fi
# 9                      Drama, Mystery, Suspense
# 10                   Action, Adventure, Fantasy
# 15     Action, Adventure, Comedy, Sci-Fi, Ecchi
# 16                        Action, Drama, Sci-Fi
# ...                                         ...
# 24880                                   UNKNOWN
# 24885                                   UNKNOWN
# 24896                                    Action
# 24898                               Avant Garde
# 24899                               Avant Garde
#
#                                                 Synopsis     Type Episodes  \
# 2      Vash the Stampede is the man with a $$60,000,0...       TV     26.0
# 9      Dr. Kenzou Tenma, an elite neurosurgeon recent...       TV     74.0
# 10     Moments prior to Naruto Uzumaki's birth, a hug...       TV    220.0
# 15     The Great Kanto Desert, a sweltering wasteland...       TV     24.0
# 16     In the dark underground city of Lux, people li...       TV     22.0
# ...                                                  ...      ...      ...
# 24880      Music video for the song Kokoro by Shikidrop.    Music      1.0
# 24885  Set in a mechanical world, Mechronicle tells t...  UNKNOWN  UNKNOWN
# 24896           No description available for this anime.  UNKNOWN  UNKNOWN
# 24898       Music video for the song Thailand by Oh Shu.    Music      1.0
# 24899  Music video for the song Energy by SLEEQ (Kim ...    Music      1.0
#
#                               Aired  ...    Source       Duration  \
# 2       Apr 1, 1998 to Sep 30, 1998  ...     Manga  24 min per ep
# 9       Apr 7, 2004 to Sep 28, 2005  ...     Manga  24 min per ep
# 10       Oct 3, 2002 to Feb 8, 2007  ...     Manga  23 min per ep
# 15      Oct 6, 2004 to Mar 30, 2005  ...     Manga  24 min per ep
# 16     Apr 17, 2003 to Sep 25, 2003  ...  Original  23 min per ep
# ...                             ...  ...       ...            ...
# 24880                  Jul 30, 2020  ...  Original          4 min
# 24885                 Not available  ...  Original        Unknown
# 24896                     2024 to ?  ...  Original        Unknown
# 24898                   Jul 3, 2014  ...  Original          4 min
# 24899                  Feb 11, 2015  ...  Original          4 min
#
#                                Rating     Rank Popularity Favorites  \
# 2           PG-13 - Teens 13 or older    328.0        246     15035
# 9                    R+ - Mild Nudity     26.0        142     47235
# 10          PG-13 - Teens 13 or older    599.0          8     76343
# 15     R - 17+ (violence & profanity)   2167.0       1546       822
# 16                   R+ - Mild Nudity    990.0        935      4786
# ...                               ...      ...        ...       ...
# 24880       PG-13 - Teens 13 or older  UNKNOWN      24664         0
# 24885                         UNKNOWN      0.0          0         0
# 24896                         UNKNOWN      0.0          0         0
# 24898       PG-13 - Teens 13 or older      0.0          0         0
# 24899       PG-13 - Teens 13 or older      0.0          0         0
#
#        Scored By  Members                                          Image URL  \
# 2       356739.0   727252  https://cdn.myanimelist.net/images/anime/7/203...
# 9       368569.0  1013100  https://cdn.myanimelist.net/images/anime/10/18...
# 10     1883772.0  2717330  https://cdn.myanimelist.net/images/anime/13/17...
# 15       53709.0   134894  https://cdn.myanimelist.net/images/anime/6/755...
# 16       54857.0   239423  https://cdn.myanimelist.net/images/anime/1027/...
# ...          ...      ...                                                ...
# 24880    UNKNOWN       31  https://cdn.myanimelist.net/images/anime/1146/...
# 24885    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1074/...
# 24896    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1135/...
# 24898    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1887/...
# 24899    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1817/...
#
#        Processed_Name
# 2              trigun
# 9             monster
# 10             naruto
# 15          sunabouzu
# 16         texhnolyze
# ...               ...
# 24880          kokoro
# 24885     mechronicle
# 24896            miru
# 24898        thailand
# 24899          energy
#
# [2278 rows x 25 columns]
# /var/folders/5c/vmwbxs651m7d5qzp8tkc7v8m0000gn/T/ipykernel_8082/2288150537.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Processed_Name'] = filtered_df['Name'].str.lower().replace(' ', '')
# (23409, 24)

# %%
#drop rows with unknown genres
unknown_rows = filtered_df[filtered_df['Genres'].str.lower() == 'unknown']
filtered_df = filtered_df.drop(unknown_rows.index)
filtered_df.shape
# Out:
# (18486, 24)

# %% [markdown]
# ## Create TF-IDF Matrix and Encoders

# %%
#create the tf-idf matrix for text comparison
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english', 
                        max_features=10000,
                        max_df=0.9,
                        min_df=2)
synopsis_vectors = tfidf.fit_transform(filtered_df['Synopsis'])

# %%
#use one-hot encoder to include genre in the recommendation
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import hstack

encoder = OneHotEncoder(sparse_output=True)

genre_encoded_sparse = encoder.fit_transform(filtered_df[['Genres']].explode('Genres'))

# %%
#include Studios in the recommendation

#filter out words from the similarity comparison
exclude_studios = ['Animation', 'Studio', 'UNKNOWN']
studios = [studio if studio not in exclude_studios else '' for studio in filtered_df['Studios']]

studios_encoder = OneHotEncoder(sparse_output=True)

studios_encoded_sparse = studios_encoder.fit_transform(filtered_df[['Studios']].explode('Studios'))

# %%
#include Rating (PG, etc) in the recommendation
rating_encoder = OneHotEncoder(sparse_output=True)
rating_encoded_sparse = rating_encoder.fit_transform(filtered_df[['Rating']].explode('Rating'))

# %%
# apply weights of importance to feature
weight_synopsis = 3.0
weight_genres = 2.0
weight_studios = 1.0
weight_rating = 1.5

weighted_synopsis = weight_synopsis * synopsis_vectors
weighted_genres = weight_genres * genre_encoded_sparse
weighted_studios = weight_studios * studios_encoded_sparse
weighted_rating = weight_rating * rating_encoded_sparse


# combine the sparse matrices horizontally (hstack)
combined_sparse_matrix = hstack([weighted_synopsis, weighted_genres, weighted_studios, weighted_rating])

# display the combined sparse matrix
print("Combined Sparse Matrix:")
print(combined_sparse_matrix)
# Out:
# Combined Sparse Matrix:
#   (0, 9808)	0.3209755583432745
#   (0, 6175)	0.15805491682044426
#   (0, 7343)	0.23433285738615384
#   (0, 3051)	0.16115743904093013
#   (0, 5987)	0.2435006534695524
#   (0, 5085)	0.1284744239471969
#   (0, 1500)	0.26589137108572464
#   (0, 9376)	0.26300062253251594
#   (0, 1862)	0.2077419711607731
#   (0, 6604)	0.22873133029278017
#   (0, 7423)	0.223816263959283
#   (0, 5518)	0.29313594765598405
#   (0, 2428)	0.31248852547728645
#   (0, 5146)	0.163336363431806
#   (0, 1991)	0.22896969341541484
#   (0, 1338)	0.2268737012618897
#   (0, 1671)	0.2690064253055781
#   (0, 1351)	0.2463453158808384
#   (0, 9790)	0.2109685575338856
#   (0, 1094)	0.2690064253055781
#   (0, 2318)	0.27928575081925683
#   (0, 4481)	0.318679843907097
#   (0, 2633)	0.3209755583432745
#   (0, 1475)	0.20488646970792113
#   (0, 6144)	0.24708911617982074
#   :	:
#   (18482, 8219)	1.1230494800226918
#   (18482, 5822)	1.033018348543619
#   (18482, 2749)	1.3996368158996542
#   (18482, 9520)	1.0018106657958648
#   (18482, 10494)	2.0
#   (18482, 12149)	1.0
#   (18482, 12268)	1.5
#   (18483, 2270)	1.8104890092753863
#   (18483, 490)	1.575267212278857
#   (18483, 778)	1.8001840898119918
#   (18483, 10694)	2.0
#   (18483, 12149)	1.0
#   (18483, 12268)	1.5
#   (18484, 2270)	1.8104890092753863
#   (18484, 490)	1.575267212278857
#   (18484, 778)	1.8001840898119918
#   (18484, 10080)	2.0
#   (18484, 12149)	1.0
#   (18484, 12268)	1.5
#   (18485, 2270)	1.8104890092753863
#   (18485, 490)	1.575267212278857
#   (18485, 778)	1.8001840898119918
#   (18485, 10095)	2.0
#   (18485, 12149)	1.0
#   (18485, 12268)	1.5

# %%
# Compute cosine similarity between all anime synopsis
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(combined_sparse_matrix)
similarity_df = pd.DataFrame(similarity, 
                             index=filtered_df['Name'], 
                             columns=filtered_df['Name'])
similarity_df.head(10)
# Out:
# Name                             Cowboy Bebop  \
# Name
# Cowboy Bebop                         1.000000
# Cowboy Bebop: Tengoku no Tobira      0.290224
# Trigun                               0.013966
# Witch Hunter Robin                   0.088382
# Bouken Ou Beet                       0.001004
# Eyeshield 21                         0.011986
# Hachimitsu to Clover                 0.000000
# Hungry Heart: Wild Striker           0.003452
# Initial D Fourth Stage               0.000000
# Monster                              0.006069
#
# Name                             Cowboy Bebop: Tengoku no Tobira    Trigun  \
# Name
# Cowboy Bebop                                            0.290224  0.013966
# Cowboy Bebop: Tengoku no Tobira                         1.000000  0.026700
# Trigun                                                  0.026700  1.000000
# Witch Hunter Robin                                      0.010819  0.141856
# Bouken Ou Beet                                          0.002696  0.008381
# Eyeshield 21                                            0.015679  0.144653
# Hachimitsu to Clover                                    0.007890  0.140709
# Hungry Heart: Wild Striker                              0.007841  0.138462
# Initial D Fourth Stage                                  0.005038  0.138462
# Monster                                                 0.008427  0.076583
#
# Name                             Witch Hunter Robin  Bouken Ou Beet  \
# Name
# Cowboy Bebop                               0.088382        0.001004
# Cowboy Bebop: Tengoku no Tobira            0.010819        0.002696
# Trigun                                     0.141856        0.008381
# Witch Hunter Robin                         1.000000        0.009193
# Bouken Ou Beet                             0.009193        1.000000
# Eyeshield 21                               0.222709        0.038466
# Hachimitsu to Clover                       0.138462        0.001348
# Hungry Heart: Wild Striker                 0.147785        0.000000
# Initial D Fourth Stage                     0.143097        0.000000
# Monster                                    0.000000        0.005868
#
# Name                             Eyeshield 21  Hachimitsu to Clover  \
# Name
# Cowboy Bebop                         0.011986              0.000000
# Cowboy Bebop: Tengoku no Tobira      0.015679              0.007890
# Trigun                               0.144653              0.140709
# Witch Hunter Robin                   0.222709              0.138462
# Bouken Ou Beet                       0.038466              0.001348
# Eyeshield 21                         1.000000              0.146615
# Hachimitsu to Clover                 0.146615              1.000000
# Hungry Heart: Wild Striker           0.147616              0.138462
# Initial D Fourth Stage               0.149528              0.156013
# Monster                              0.007006              0.000000
#
# Name                             Hungry Heart: Wild Striker  \
# Name
# Cowboy Bebop                                       0.003452
# Cowboy Bebop: Tengoku no Tobira                    0.007841
# Trigun                                             0.138462
# Witch Hunter Robin                                 0.147785
# Bouken Ou Beet                                     0.000000
# Eyeshield 21                                       0.147616
# Hachimitsu to Clover                               0.138462
# Hungry Heart: Wild Striker                         1.000000
# Initial D Fourth Stage                             0.154368
# Monster                                            0.000000
#
# Name                             Initial D Fourth Stage   Monster  ...  \
# Name                                                               ...
# Cowboy Bebop                                   0.000000  0.006069  ...
# Cowboy Bebop: Tengoku no Tobira                0.005038  0.008427  ...
# Trigun                                         0.138462  0.076583  ...
# Witch Hunter Robin                             0.143097  0.000000  ...
# Bouken Ou Beet                                 0.000000  0.005868  ...
# Eyeshield 21                                   0.149528  0.007006  ...
# Hachimitsu to Clover                           0.156013  0.000000  ...
# Hungry Heart: Wild Striker                     0.154368  0.000000  ...
# Initial D Fourth Stage                         1.000000  0.000000  ...
# Monster                                        0.000000  1.000000  ...
#
# Name                             Beauty and the Brawn  4 Week Lovers  \
# Name
# Cowboy Bebop                                 0.000000       0.014172
# Cowboy Bebop: Tengoku no Tobira              0.000000       0.003639
# Trigun                                       0.000000       0.024941
# Witch Hunter Robin                           0.002000       0.002560
# Bouken Ou Beet                               0.000000       0.002842
# Eyeshield 21                                 0.003052       0.029993
# Hachimitsu to Clover                         0.007798       0.018634
# Hungry Heart: Wild Striker                   0.000000       0.007718
# Initial D Fourth Stage                       0.000000       0.004035
# Monster                                      0.000000       0.009990
#
# Name                             Die, Please!  Miru  \
# Name
# Cowboy Bebop                         0.000000   0.0
# Cowboy Bebop: Tengoku no Tobira      0.000000   0.0
# Trigun                               0.007177   0.0
# Witch Hunter Robin                   0.002575   0.0
# Bouken Ou Beet                       0.000000   0.0
# Eyeshield 21                         0.006829   0.0
# Hachimitsu to Clover                 0.000000   0.0
# Hungry Heart: Wild Striker           0.016633   0.0
# Initial D Fourth Stage               0.012452   0.0
# Monster                              0.012997   0.0
#
# Name                             Wo Mengjian ni Mengjian wo  Thailand  \
# Name
# Cowboy Bebop                                            0.0  0.000000
# Cowboy Bebop: Tengoku no Tobira                         0.0  0.000000
# Trigun                                                  0.0  0.138462
# Witch Hunter Robin                                      0.0  0.138462
# Bouken Ou Beet                                          0.0  0.000000
# Eyeshield 21                                            0.0  0.138462
# Hachimitsu to Clover                                    0.0  0.138462
# Hungry Heart: Wild Striker                              0.0  0.138462
# Initial D Fourth Stage                                  0.0  0.138462
# Monster                                                 0.0  0.000000
#
# Name                               Energy  Wu Nao Monu  Bu Xing Si: Yuan Qi  \
# Name
# Cowboy Bebop                     0.000000     0.000000             0.000000
# Cowboy Bebop: Tengoku no Tobira  0.000000     0.000000             0.000000
# Trigun                           0.138462     0.138462             0.138462
# Witch Hunter Robin               0.138462     0.138462             0.138462
# Bouken Ou Beet                   0.000000     0.000000             0.000000
# Eyeshield 21                     0.138462     0.138462             0.138462
# Hachimitsu to Clover             0.138462     0.138462             0.138462
# Hungry Heart: Wild Striker       0.138462     0.138462             0.138462
# Initial D Fourth Stage           0.138462     0.138462             0.138462
# Monster                          0.000000     0.000000             0.000000
#
# Name                             Di Yi Xulie
# Name
# Cowboy Bebop                        0.000000
# Cowboy Bebop: Tengoku no Tobira     0.000000
# Trigun                              0.138462
# Witch Hunter Robin                  0.138462
# Bouken Ou Beet                      0.000000
# Eyeshield 21                        0.138462
# Hachimitsu to Clover                0.138462
# Hungry Heart: Wild Striker          0.138462
# Initial D Fourth Stage              0.138462
# Monster                             0.000000
#
# [10 rows x 18486 columns]

# %%
# anime list 
anime_list = similarity_df.columns.values


# sample anime
anime = 'Death Note'

# top recommendation movie count
top_n = 10

# get anime similarity records
anime_sim = similarity_df[similarity_df.index == anime].values[0]

# get animes sorted by similarity
sorted_anime_ids = np.argsort(anime_sim)[::-1]

# get recommended anime names
recommended_anime = anime_list[sorted_anime_ids[1:top_n+1]]

print('\n\nTop Recommended Anime for:', anime, 'are:-\n', recommended_anime)
# Out:
# Top Recommended Anime for: Death Note are:-
#  ['Death Note: Rewrite' 'Munou na Nana' 'Death Parade'
#  'Majin Tantei Nougami Neuro' 'Warau Salesman Special Program'
#  'Rainbow: Nisha Rokubou no Shichinin' 'Kamisama no Inai Nichiyoubi'
#  'Hunter x Hunter Movie 2: The Last Mission' 'ChäoS;HEAd'
#  'Touhai Densetsu Akagi: Yami ni Maiorita Tensai']

# %%
def content_anime_recommender(
    input_anime, similarity_database=similarity_df, anime_database_list=anime_list, top_n=10):
    
    # get anime similarity records
    anime_sim = similarity_database[similarity_database.index == input_anime].values[0]
    
    # get anime sorted by similarity
    sorted_anime_ids = np.argsort(anime_sim)[::-1]
    
    # get recommended anime names
    recommended_anime = anime_database_list[sorted_anime_ids[1:top_n+1]]
    
    print('\n\nTop Recommended Anime for:', input_anime, 'are:-\n', recommended_anime)

sample_anime = ['Death Note', 'Cowboy Bebop', 'Bleach', 
                 'Fruits Basket', 'Monster']
                 
for i in sample_anime:
    content_anime_recommender(i)
# Out:
# Top Recommended Anime for: Death Note are:-
#  ['Death Note: Rewrite' 'Munou na Nana' 'Death Parade'
#  'Majin Tantei Nougami Neuro' 'Warau Salesman Special Program'
#  'Rainbow: Nisha Rokubou no Shichinin' 'Kamisama no Inai Nichiyoubi'
#  'Hunter x Hunter Movie 2: The Last Mission' 'ChäoS;HEAd'
#  'Touhai Densetsu Akagi: Yami ni Maiorita Tensai']
#
#
# Top Recommended Anime for: Cowboy Bebop are:-
#  ['Koukaku Kidoutai: Stand Alone Complex' 'Cowboy Bebop: Tengoku no Tobira'
#  'Hate no issen EPISODE ZERO' 'SSSS.Gridman'
#  'Cowboy Bebop: Yose Atsume Blues' 'Kidou Senshi Gundam SEED'
#  'Kidou Senshi Gundam 00 Second Season' 'Kakumeiki Valvrave'
#  'Double Decker! Doug & Kirill' 'Uchuu no Senshi']
#
#
# Top Recommended Anime for: Bleach are:-
#  ['Bleach Movie 3: Fade to Black - Kimi no Na wo Yobu'
#  'Bleach Movie 1: Memories of Nobody' 'Bleach Movie 4: Jigoku-hen'
#  'Bleach: The Sealed Sword Frenzy' 'Bleach: Sennen Kessen-hen'
#  'Bleach Movie 2: The DiamondDust Rebellion - Mou Hitotsu no Hyourinmaru'
#  'Juuni Kokuki' 'Boruto: Naruto the Movie'
#  'Naruto: Shippuuden Movie 6 - Road to Ninja'
#  'Boruto: Naruto Next Generations']
#
#
# Top Recommended Anime for: Fruits Basket are:-
#  ['Fruits Basket 1st Season' 'Fruits Basket 2nd Season'
#  'Fruits Basket: The Final' 'Clannad: After Story' 'Mizuiro (2003)' 'Air'
#  'Sora no Aosa wo Shiru Hito yo' 'Kokoro Connect: Michi Random'
#  'Wind: A Breath of Heart (TV)' 'Clannad']
#
#
# Top Recommended Anime for: Monster are:-
#  ['Monster Special Edition' 'Monster Extra: Hottan' 'Black Jack'
#  'Doctor Chichibuyama'
#  'Sakurako-san no Ashimoto ni wa Shitai ga Umatteiru' 'Shion no Ou'
#  'Hanada Shounen-shi' 'Claymore' 'Youjuu Toshi' 'Juubee Ninpuuchou']

# %%
df_users_ratings = pd.read_csv('../data/users-score-2023.csv')
df_users_ratings[df_users_ratings['Anime Title'] == 'Death Note'].head()
print(df_users_ratings.shape)
# Out:
# (24325191, 5)

# %% [markdown]
# ### Deriving ground truth using threshold-based approach

# %%
# find relevant anime for ground truth, set ratings above 7
threshold = 7

sample_size = 10000

# take sample from df_users_ratings
sample_data = df_users_ratings.sample(n=sample_size, random_state=42)  #set random_state for reproducibility

#create ground truth based on the threshold
avg_ratings = sample_data.groupby('Anime Title')['rating'].mean()
print(avg_ratings)

# Filter out titles where the average rating is greater than the threshold
liked_anime = avg_ratings[avg_ratings > threshold].index.tolist()

# group by anime and create the ground_truths dictionary
ground_truths = df_users_ratings.groupby('Anime Title')['Anime Title'].apply(lambda x: liked_anime).to_dict()


#print out the items
print (set(ground_truths))
# Out:
# Anime Title
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi     8.000000
# "Bungaku Shoujo" Movie                        7.750000
# "Oshi no Ko"                                  8.500000
# .hack//G.U. Returner                          7.000000
# .hack//G.U. Trilogy: Parody Mode              6.000000
#                                                ...
# xxxHOLiC                                      8.714286
# xxxHOLiC Movie: Manatsu no Yoru no Yume       6.833333
# xxxHOLiC Rou                                 10.000000
# xxxHOLiC Shunmuki                             7.500000
# xxxHOLiC◆Kei                                  7.333333
# Name: rating, Length: 3148, dtype: float64
# {'Tottemo! Luckyman', 'Norakuro Nitouhei: Kyouren no Maki', 'Doukyuusei 2 (OVA)', 'Kingdom 3rd Season', 'Kaitou Lupin: 813 no Nazo', 'Dinner Bell', 'Momoya Norihei Anime CM', 'Tales of Crestoria: Toga Waga wo Shoite Kare wa Tatsu', 'AI no Idenshi', 'Rifle Is Beautiful', 'Love Letter (Music)', 'Overlord III', 'Koi☆Sento', 'Kyoto Animation: Megane-hen', 'Suzuka', 'Comics', 'Elf wo Karu Mono-tachi', 'Joint', 'Kero Kero Keroppi no Ganbare! Keroppooz', 'Mushishi', 'Shin Gakkou no Yuurei', 'Jungle de Ikou!', 'Ichiban Ushiro no Daimaou Specials', 'Umiyuri Kaiteitan', 'Minihams no Kekkon Song', 'Sarasoujuu no Hana no Iro', 'Tachiguishi Retsuden', 'Koutetsu no Vendetta Episode 0', 'Eromame', 'Choujikuu Seiki Orguss 02', 'Heavy Object: Dai 37 Kidou Seihi Daitai - Sakusen Kiroku', 'Yume Oukoku to Nemureru 100-nin no Ouji-sama: Short Stories', 'Kappa no Sanpei', 'Daremo Shiranai', 'Higashi no Eden: Falling Down', 'Fortune Dogs', 'Bakuman.: Deraman.', '6 Angels', 'Who Am I?', 'Yomadoiko', 'Blue Reflection Ray!', 'Shin Koihime†Musou OVA Omake', 'Nido to Mezamenu Komoriuta', 'Koukaku Kidoutai: Ghost Chaser', 'The Place Where We Were', 'Yoru no Okite', 'Aoi Taiken', 'Nanmu Ichibyousokusai', 'Miyakawa-ke no Kuufuku', 'Bible Black Gaiden', 'Gunma-chan', 'Mahou no Tenshi Creamy Mami: Zutto Kitto Motto', 'Naruto: Shippuuden Movie 5 - Blood Prison', 'Non Non Biyori Repeat: Hotaru ga Tanoshinda', 'Battle Royal High School', 'Memory (ONA)', 'Nozo x Kimi', 'Kuroko no Basket 2nd Season NG-shuu', 'Wonderful Rush', 'Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no Shou 2 - Tamashii', 'Peace Maker Kurogane Special', 'Bucket de Gohan', 'The Crater', 'Gibomai', 'Gate: Jieitai Kanochi nite, Kaku Tatakaeri', 'Ten no Kawa', 'Yuragi-sou no Yuuna-san OVA', 'Princess Principal Picture Drama', 'Ari to Kirigirisu', 'Transformers Superlink', 'Tsuma Tsuma', 'Tentacle and Witches', 'Last Exile: Ginyoku no Fam - Adjournment', 'Sacred Seven', 'Ushiro no Shoumen Daare', 'Miboujin Nikki: Akogare no Ano Hito to Hitotsu Yane no Shita', 'Glasslip', 'Hulu Xiongdi', 'Quails', 'Cutey Honey Flash: The Movie', 'Himitsu Spark', 'Shi Wan Ge Leng Xiaohua', 'Renai Fuyou Gakuha The Animation', 'Baby Baachan', 'Ulysses: Jehanne Darc to Renkin no Kishi', 'Space☆Dandy 2nd Season Picture Drama', 'Maro no Kanja wa Gatenkei', 'Bakuretsu Hunters OVA', 'KanColle: Itsuka Ano Umi de', 'Senki Zesshou Symphogear AXZ', 'Wacha Wacha the Movie', 'Jue Shi Wu Hun', 'Boku dake no Hentai Kanojo Motto♥ The Animation', 'Ninpuu Kamui Gaiden', 'Toaru Hikuushi e no Tsuioku', 'Yamatarou Kaeru', 'Padak Padak', 'Goulart Knights: Evoked the Beginning Black', 'Saikyou Bushouden: Sangoku Engi', 'Hypnosis Mic: Division Rap Battle - Rhyme Anima', 'Eternity', 'The Primitives: Bongo and Grunge', 'Ladies versus Butlers!', 'Sharedol', 'Minna Agechau♡', 'Peace Shitenchou', 'RESTART POiNTER', 'Ningyohime', 'Play Ball 2nd', 'Shikabane Hime: Aka', 'Tobacco to Hai', 'New Game!', 'Daishizen no Majuu: Bagi', 'Code Geass: Fukkatsu no Lelouch Picture Drama', 'Friends: Mononoke Shima no Naki', 'Nazotokine', 'Nudist Beach ni Shuugaku Ryokou de!! The Animation Special', 'Ai Tenshi Densetsu Wedding Peach', 'Manga Edo Erobanashi', 'Makeruna! Makendou', 'Trouble Evocation', 'Kanojo ga Mimai ni Konai Wake', 'Tenchi Muyou! Manatsu no Eve', 'Maou-sama, "Petit" Retry!', 'BanG Dream! Garupa☆Pico', 'Inazma Delivery', 'Oyome-sama Honey Days♥', 'YAT Anshin! Uchuu Ryokou', 'Dekobou no Jidousha Ryokou', 'Kyonyuu Fantasy', 'Mazinger Z tai Ankoku Daishougun', 'Mahou Shoujo Magical Destroyers', 'Ensemble Stars!! Road to Show!!', 'Gasshin Sentai Mechander Robo', 'COLORs', 'Marco: Haha wo Tazunete Sanzenri', 'Ya-Ne-Sen a Go Go', '3-tsu no Kumo', 'Gridman Universe', 'Mayonaka wa Junketsu', 'Pittoshite! Marmalade', 'High Score Girl II', 'Gokujo.: Souda Onsen ni Ikou!!', 'Doraemon Movie 24: Nobita to Fushigi Kaze Tsukai', 'Hyakujuu-Ou GoLion', 'Crayon Shin-chan Gaiden: Alien vs. Shinnosuke', 'Yes! BanG_Dream!', 'Mahou Shoujo Lyrical Nanoha: Reflection', ' ...

# %%
#precision at n: measures the proportion of relevant items among the top n
def content_anime_recommender2(
    top_n, input_anime, ground_truths, similarity_database=similarity_df, anime_database_list=anime_list):
    
    # get anime similarity records
    anime_sim = similarity_database[similarity_database.index == input_anime].values[0]
    
    # get anime sorted by similarity
    sorted_anime_ids = np.argsort(anime_sim)[::-1]
    
    # get recommended anime names
    recommended_anime = anime_database_list[sorted_anime_ids[1:top_n+1]]
    
    # calculate precision at n
    intersection = set(recommended_anime) & set(ground_truths)
    precision_at_n = len(intersection) / top_n
    rounded_precision = round(precision_at_n, 2)
    
    print('\n\nTop Recommended Anime for ', input_anime, recommended_anime)
    print('\nPrecision at', top_n, '=', rounded_precision)

#select 2 highly rated and 2 lower rated titles
sample_anime2 = ['Death Note', 'Jigoku Shoujo Mitsuganae', 'Xian Yu Ge', 'Higenashi Gogejabaru']

for i in sample_anime2:
    content_anime_recommender2(10, i, ground_truths)
# Out:
# Top Recommended Anime for  Death Note ['Death Note: Rewrite' 'Munou na Nana' 'Death Parade'
#  'Majin Tantei Nougami Neuro' 'Warau Salesman Special Program'
#  'Rainbow: Nisha Rokubou no Shichinin' 'Kamisama no Inai Nichiyoubi'
#  'Hunter x Hunter Movie 2: The Last Mission' 'ChäoS;HEAd'
#  'Touhai Densetsu Akagi: Yami ni Maiorita Tensai']
#
# Precision at 10 = 1.0
#
#
# Top Recommended Anime for  Jigoku Shoujo Mitsuganae ['Jigoku Shoujo: Yoi no Togi' 'Jigoku Shoujo' '18if' "Le Chevalier D'Eon"
#  'Pet' 'Un-Go: Inga-ron' 'Jigoku Shoujo Futakomori' 'Tactics'
#  'Muhyo to Rouji no Mahouritsu Soudan Jimusho 2nd Season'
#  'Muhyo to Rouji no Mahouritsu Soudan Jimusho']
#
# Precision at 10 = 1.0
#
#
# Top Recommended Anime for  Xian Yu Ge ['Mao Zhi Ming Episode 5.5' 'Chinkoroheibei Tamatebako'
#  'Atelier Petros Joukuu Gekijou: Sentaku Shima no Sentaku Tori'
#  'Minna Tomodachi' 'Seaside-sou no Aquakko'
#  'Qin Shi Mingyue: Xiao Chuangjianghu' 'Nulu-chan to Boku'
#  'Kaeru Ouji to Imomushi Henry' 'Higenashi Gogejabaru' 'Happy Kappy']
#
# Precision at 10 = 0.6
#
#
# Top Recommended Anime for  Higenashi Gogejabaru ['Gokuu no Daibouken Pilot' 'Kaijuu no Ballad' 'Nulu-chan to Boku'
#  "DS Anime Soushuuhen '98" 'Xian Yu Ge' 'Obake no... Holly'
#  'Mayutoro The Toons' 'Yu Jian Tuzki' 'Mao Zhi Ming 2nd Season'
#  'Komaneko no Christmas: Maigo ni Natta Present']
#
# Precision at 10 = 0.7

# %%
for i in sample_anime2:
    content_anime_recommender2(5, i, ground_truths)
# Out:
# Top Recommended Anime for  Death Note ['Death Note: Rewrite' 'Munou na Nana' 'Death Parade'
#  'Majin Tantei Nougami Neuro' 'Warau Salesman Special Program']
#
# Precision at 5 = 1.0
#
#
# Top Recommended Anime for  Jigoku Shoujo Mitsuganae ['Jigoku Shoujo: Yoi no Togi' 'Jigoku Shoujo' '18if' "Le Chevalier D'Eon"
#  'Pet']
#
# Precision at 5 = 1.0
#
#
# Top Recommended Anime for  Xian Yu Ge ['Mao Zhi Ming Episode 5.5' 'Chinkoroheibei Tamatebako'
#  'Atelier Petros Joukuu Gekijou: Sentaku Shima no Sentaku Tori'
#  'Minna Tomodachi' 'Seaside-sou no Aquakko']
#
# Precision at 5 = 0.6
#
#
# Top Recommended Anime for  Higenashi Gogejabaru ['Gokuu no Daibouken Pilot' 'Kaijuu no Ballad' 'Nulu-chan to Boku'
#  "DS Anime Soushuuhen '98" 'Xian Yu Ge']
#
# Precision at 5 = 0.8

# %%
for i in sample_anime2:
    content_anime_recommender2(15, i, ground_truths)
# Out:
# Top Recommended Anime for  Death Note ['Death Note: Rewrite' 'Munou na Nana' 'Death Parade'
#  'Majin Tantei Nougami Neuro' 'Warau Salesman Special Program'
#  'Rainbow: Nisha Rokubou no Shichinin' 'Kamisama no Inai Nichiyoubi'
#  'Hunter x Hunter Movie 2: The Last Mission' 'ChäoS;HEAd'
#  'Touhai Densetsu Akagi: Yami ni Maiorita Tensai' 'Btooom!'
#  'Juubee Ninpuuchou: Ryuuhougyoku-hen' 'Boogiepop wa Warawanai (2019)'
#  'Vampire Hunter D (2000)' 'Vampire Hunter']
#
# Precision at 15 = 1.0
#
#
# Top Recommended Anime for  Jigoku Shoujo Mitsuganae ['Jigoku Shoujo: Yoi no Togi' 'Jigoku Shoujo' '18if' "Le Chevalier D'Eon"
#  'Pet' 'Un-Go: Inga-ron' 'Jigoku Shoujo Futakomori' 'Tactics'
#  'Muhyo to Rouji no Mahouritsu Soudan Jimusho 2nd Season'
#  'Muhyo to Rouji no Mahouritsu Soudan Jimusho'
#  'Honto ni Atta Gakkou Kaidan' 'Saint Luminous Jogakuin' 'Sakurada Reset'
#  'xxxHOLiC Rou' 'Mahoutsukai no Yoru']
#
# Precision at 15 = 0.93
#
#
# Top Recommended Anime for  Xian Yu Ge ['Mao Zhi Ming Episode 5.5' 'Chinkoroheibei Tamatebako'
#  'Atelier Petros Joukuu Gekijou: Sentaku Shima no Sentaku Tori'
#  'Minna Tomodachi' 'Seaside-sou no Aquakko'
#  'Qin Shi Mingyue: Xiao Chuangjianghu' 'Nulu-chan to Boku'
#  'Kaeru Ouji to Imomushi Henry' 'Higenashi Gogejabaru' 'Happy Kappy'
#  'Osu no Buu-chan' 'Cinterrier-jou no Hanamuko' 'Gokuu no Daibouken Pilot'
#  'Nikoniko, Pun' 'Kenkou Takarabune Sukoyaka 7']
#
# Precision at 15 = 0.47
#
#
# Top Recommended Anime for  Higenashi Gogejabaru ['Gokuu no Daibouken Pilot' 'Kaijuu no Ballad' 'Nulu-chan to Boku'
#  "DS Anime Soushuuhen '98" 'Xian Yu Ge' 'Obake no... Holly'
#  'Mayutoro The Toons' 'Yu Jian Tuzki' 'Mao Zhi Ming 2nd Season'
#  'Komaneko no Christmas: Maigo ni Natta Present'
#  'Shanhe Jian Xin Xiao Juchang' 'Happy Kappy'
#  'Baka Mukashibanashi Movie: Jijii Wars'
#  'Fire Emblem Heroes: Chibi Playhouse'
#  'Ponkotsu Quest x Gatchaman Special']
#
# Precision at 15 = 0.67

# %% [markdown]
# # Cosine TF-IDF (Term Frequency-Inverse Document Frequency) similarity

# %% [markdown]
# TF-IDF is measure of how frequent a term appears in a text and how frequent the term appears across the collection of documents.
#
# The TF-IDF score multiplies TF x IDF values. A higher score means the term is more significant.
#
# After calculating the TF-IDF score, we take the cosine of the angle between the sentences and the terms.

# %%
import pandas as pd
import numpy as np

df_anime = pd.read_csv('../data/anime-dataset-2023.csv')
df_anime.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
#                                             Synopsis   Type Episodes  \
# 0  Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1  Another day, another bounty—such is the life o...  Movie      1.0
# 2  Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3  Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4  It is the dark century and the people are suff...     TV     52.0
#
#                           Aired  ...         Studios    Source       Duration  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...         Sunrise  Original  24 min per ep
# 1                   Sep 1, 2001  ...           Bones  Original    1 hr 55 min
# 2   Apr 1, 1998 to Sep 30, 1998  ...        Madhouse     Manga  24 min per ep
# 3   Jul 3, 2002 to Dec 25, 2002  ...         Sunrise  Original  25 min per ep
# 4  Sep 30, 2004 to Sep 29, 2005  ...  Toei Animation     Manga  23 min per ep
#
#                            Rating    Rank Popularity Favorites Scored By  \
# 0  R - 17+ (violence & profanity)    41.0         43     78525  914193.0
# 1  R - 17+ (violence & profanity)   189.0        602      1448  206248.0
# 2       PG-13 - Teens 13 or older   328.0        246     15035  356739.0
# 3       PG-13 - Teens 13 or older  2764.0       1795       613   42829.0
# 4                   PG - Children  4240.0       5126        14    6413.0
#
#    Members                                          Image URL
# 0  1771505  https://cdn.myanimelist.net/images/anime/4/196...
# 1   360978  https://cdn.myanimelist.net/images/anime/1439/...
# 2   727252  https://cdn.myanimelist.net/images/anime/7/203...
# 3   111931  https://cdn.myanimelist.net/images/anime/10/19...
# 4    15001  https://cdn.myanimelist.net/images/anime/7/215...
#
# [5 rows x 24 columns]

# %%
df_anime.shape
# Out:
# (24905, 24)

# %%
#basic filtering for duplicates

duplicates_all = df_anime[df_anime.duplicated()]
print("All Duplicates:")
print(len(duplicates_all))

duplicates = df_anime[df_anime.duplicated(['Name'])].sort_values(by='Name')
print("Duplicates based on Name:")
print(len(duplicates))
duplicates = duplicates[['anime_id', 'Name']]
print(duplicates)

df_anime_new = df_anime.drop_duplicates(['Name'])
print("Cleaned anime shape: {} \n".format(df_anime_new.shape))
print("Old anime shape: {}".format(df_anime.shape))
# Out:
# All Duplicates:
# 0
# Duplicates based on Name:
# 4
#        anime_id       Name
# 24840     55658  Awakening
# 24586     55351  Azur Lane
# 24807     55610   Souseiki
# 24781     55582     Utopia
# Cleaned anime shape: (24901, 24)
#
# Old anime shape: (24905, 24)

# %%
#filter out certain genre
to_exclude = df_anime[df_anime['Genres'].str.contains('Hentai', case=False, na=False)]
filtered_df = df_anime[~df_anime.index.isin(to_exclude.index)]
filtered_df.shape
# Out:
# (23419, 24)

# %%
# Convert Name column to lowercase and remove spaces
filtered_df['Processed_Name'] = filtered_df['Name'].str.lower().replace(' ', '')

# Filter out rows with titles in lowercase and without spaces
duplicate_rows = filtered_df[filtered_df.duplicated(subset='Processed_Name', keep=False) | ~filtered_df.duplicated(subset='Processed_Name', keep=False) & ~filtered_df['Processed_Name'].str.contains(' ')]

print(duplicate_rows)
# Filter out rows that are upper case and have no spacing, e.g. between Death Note and DEATHNOTE, keep Death Note
filtered_df = filtered_df[~((filtered_df['Processed_Name'].isin(duplicate_rows['Processed_Name'])) & (filtered_df.duplicated(subset='Processed_Name', keep=False)))]

# Drop the intermediate 'Processed_Name' column
filtered_df = filtered_df.drop(columns='Processed_Name')

filtered_df.shape
# Out:
#        anime_id         Name English name   Other name    Score  \
# 2             6       Trigun       Trigun        トライガン     8.22
# 9            19      Monster      Monster        モンスター     8.87
# 10           20       Naruto       Naruto          ナルト     7.99
# 15           25    Sunabouzu  Desert Punk         砂ぼうず     7.38
# 16           26   Texhnolyze   Texhnolyze   TEXHNOLYZE     7.76
# ...         ...          ...          ...          ...      ...
# 24880     55707       Kokoro      UNKNOWN            心  UNKNOWN
# 24885     55716  Mechronicle  Mechronicle  Mechronicle  UNKNOWN
# 24896     55727         Miru      UNKNOWN           未ル  UNKNOWN
# 24898     55729     Thailand      UNKNOWN     Thailand  UNKNOWN
# 24899     55730       Energy      UNKNOWN       Energy  UNKNOWN
#
#                                          Genres  \
# 2                     Action, Adventure, Sci-Fi
# 9                      Drama, Mystery, Suspense
# 10                   Action, Adventure, Fantasy
# 15     Action, Adventure, Comedy, Sci-Fi, Ecchi
# 16                        Action, Drama, Sci-Fi
# ...                                         ...
# 24880                                   UNKNOWN
# 24885                                   UNKNOWN
# 24896                                    Action
# 24898                               Avant Garde
# 24899                               Avant Garde
#
#                                                 Synopsis     Type Episodes  \
# 2      Vash the Stampede is the man with a $$60,000,0...       TV     26.0
# 9      Dr. Kenzou Tenma, an elite neurosurgeon recent...       TV     74.0
# 10     Moments prior to Naruto Uzumaki's birth, a hug...       TV    220.0
# 15     The Great Kanto Desert, a sweltering wasteland...       TV     24.0
# 16     In the dark underground city of Lux, people li...       TV     22.0
# ...                                                  ...      ...      ...
# 24880      Music video for the song Kokoro by Shikidrop.    Music      1.0
# 24885  Set in a mechanical world, Mechronicle tells t...  UNKNOWN  UNKNOWN
# 24896           No description available for this anime.  UNKNOWN  UNKNOWN
# 24898       Music video for the song Thailand by Oh Shu.    Music      1.0
# 24899  Music video for the song Energy by SLEEQ (Kim ...    Music      1.0
#
#                               Aired  ...    Source       Duration  \
# 2       Apr 1, 1998 to Sep 30, 1998  ...     Manga  24 min per ep
# 9       Apr 7, 2004 to Sep 28, 2005  ...     Manga  24 min per ep
# 10       Oct 3, 2002 to Feb 8, 2007  ...     Manga  23 min per ep
# 15      Oct 6, 2004 to Mar 30, 2005  ...     Manga  24 min per ep
# 16     Apr 17, 2003 to Sep 25, 2003  ...  Original  23 min per ep
# ...                             ...  ...       ...            ...
# 24880                  Jul 30, 2020  ...  Original          4 min
# 24885                 Not available  ...  Original        Unknown
# 24896                     2024 to ?  ...  Original        Unknown
# 24898                   Jul 3, 2014  ...  Original          4 min
# 24899                  Feb 11, 2015  ...  Original          4 min
#
#                                Rating     Rank Popularity Favorites  \
# 2           PG-13 - Teens 13 or older    328.0        246     15035
# 9                    R+ - Mild Nudity     26.0        142     47235
# 10          PG-13 - Teens 13 or older    599.0          8     76343
# 15     R - 17+ (violence & profanity)   2167.0       1546       822
# 16                   R+ - Mild Nudity    990.0        935      4786
# ...                               ...      ...        ...       ...
# 24880       PG-13 - Teens 13 or older  UNKNOWN      24664         0
# 24885                         UNKNOWN      0.0          0         0
# 24896                         UNKNOWN      0.0          0         0
# 24898       PG-13 - Teens 13 or older      0.0          0         0
# 24899       PG-13 - Teens 13 or older      0.0          0         0
#
#        Scored By  Members                                          Image URL  \
# 2       356739.0   727252  https://cdn.myanimelist.net/images/anime/7/203...
# 9       368569.0  1013100  https://cdn.myanimelist.net/images/anime/10/18...
# 10     1883772.0  2717330  https://cdn.myanimelist.net/images/anime/13/17...
# 15       53709.0   134894  https://cdn.myanimelist.net/images/anime/6/755...
# 16       54857.0   239423  https://cdn.myanimelist.net/images/anime/1027/...
# ...          ...      ...                                                ...
# 24880    UNKNOWN       31  https://cdn.myanimelist.net/images/anime/1146/...
# 24885    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1074/...
# 24896    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1135/...
# 24898    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1887/...
# 24899    UNKNOWN        0  https://cdn.myanimelist.net/images/anime/1817/...
#
#        Processed_Name
# 2              trigun
# 9             monster
# 10             naruto
# 15          sunabouzu
# 16         texhnolyze
# ...               ...
# 24880          kokoro
# 24885     mechronicle
# 24896            miru
# 24898        thailand
# 24899          energy
#
# [2278 rows x 25 columns]
# /var/folders/5c/vmwbxs651m7d5qzp8tkc7v8m0000gn/T/ipykernel_4044/2288150537.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Processed_Name'] = filtered_df['Name'].str.lower().replace(' ', '')
# (23409, 24)

# %%
#drop rows with unknown genres
unknown_rows = filtered_df[filtered_df['Genres'].str.lower() == 'unknown']
filtered_df = filtered_df.drop(unknown_rows.index)
filtered_df.shape
# Out:
# (18486, 24)

# %%
#create the tf-idf matrix for text comparison
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english')
synopsis_vectors = tfidf.fit_transform(filtered_df['Synopsis'])

# %%
#use one-hot encoder to include genre in the recommendation
from sklearn.preprocessing import OneHotEncoder
from scipy.sparse import hstack

encoder = OneHotEncoder(sparse_output=True)

genre_encoded_sparse = encoder.fit_transform(filtered_df[['Genres']].explode('Genres'))

# %%
#include Studios in the recommendation

#filter out words from the similarity comparison
exclude_studios = ['Animation', 'Studio', 'UNKNOWN']
studios = [studio if studio not in exclude_studios else '' for studio in filtered_df['Studios']]

studios_encoder = OneHotEncoder(sparse_output=True)

studios_encoded_sparse = encoder.fit_transform(filtered_df[['Studios']].explode('Studios'))

# %%
# combine the sparse matrices horizontally (hstack)
combined_sparse_matrix = hstack([synopsis_vectors, genre_encoded_sparse, studios_encoded_sparse])

# display the combined sparse matrix
print("Combined Sparse Matrix:")
print(combined_sparse_matrix)
# Out:
# Combined Sparse Matrix:
#   (0, 44873)	0.09473567569169065
#   (0, 28966)	0.046649780496261554
#   (0, 33878)	0.06916315278280448
#   (0, 12900)	0.04756548741308503
#   (0, 27918)	0.07186902036053307
#   (0, 23360)	0.03791912201838669
#   (0, 6799)	0.07847762250313407
#   (0, 43046)	0.0776244204124312
#   (0, 8000)	0.06131487428208387
#   (0, 31010)	0.06750986660476928
#   (0, 24511)	0.11188802075966059
#   (0, 34191)	0.0660591887632018
#   (0, 25364)	0.0865188371789169
#   (0, 10306)	0.0922307348253924
#   (0, 23591)	0.04820859517965824
#   (0, 8463)	0.0675802192870711
#   (0, 6083)	0.06696158890308303
#   (0, 7417)	0.0793970282294058
#   (0, 6125)	0.07270862016382937
#   (0, 44823)	0.06226719863292278
#   (0, 4927)	0.0793970282294058
#   (0, 9838)	0.08243096281688525
#   (0, 8150)	0.11188802075966059
#   (0, 44457)	0.12010485927243436
#   (0, 4538)	0.12010485927243436
#   :	:
#   (18482, 34705)	0.48231210772650307
#   (18482, 37622)	0.48231210772650307
#   (18482, 18035)	0.44931526874803385
#   (18482, 21494)	0.3703763559632167
#   (18482, 37964)	0.2159793638284476
#   (18482, 27039)	0.19866501851463952
#   (18482, 11833)	0.2691712827138955
#   (18482, 43753)	0.19266331014264174
#   (18482, 46976)	1.0
#   (18482, 48631)	1.0
#   (18483, 9688)	0.6034963364251288
#   (18483, 2221)	0.525089070759619
#   (18483, 3417)	0.600061363270664
#   (18483, 47176)	1.0
#   (18483, 48631)	1.0
#   (18484, 9688)	0.6034963364251288
#   (18484, 2221)	0.525089070759619
#   (18484, 3417)	0.600061363270664
#   (18484, 46562)	1.0
#   (18484, 48631)	1.0
#   (18485, 9688)	0.6034963364251288
#   (18485, 2221)	0.525089070759619
#   (18485, 3417)	0.600061363270664
#   (18485, 46577)	1.0
#   (18485, 48631)	1.0

# %%
# Compute cosine similarity between all anime synopsis
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(combined_sparse_matrix)
similarity_df = pd.DataFrame(similarity, 
                             index=filtered_df['Name'], 
                             columns=filtered_df['Name'])
similarity_df.head(10)
# Out:
# Name                             Cowboy Bebop  \
# Name
# Cowboy Bebop                         1.000000
# Cowboy Bebop: Tengoku no Tobira      0.087892
# Trigun                               0.006507
# Witch Hunter Robin                   0.346858
# Bouken Ou Beet                       0.000493
# Eyeshield 21                         0.005552
# Hachimitsu to Clover                 0.000000
# Hungry Heart: Wild Striker           0.001693
# Initial D Fourth Stage               0.000000
# Monster                              0.003103
#
# Name                             Cowboy Bebop: Tengoku no Tobira    Trigun  \
# Name
# Cowboy Bebop                                            0.087892  0.006507
# Cowboy Bebop: Tengoku no Tobira                         1.000000  0.012497
# Trigun                                                  0.012497  1.000000
# Witch Hunter Robin                                      0.005476  0.001689
# Bouken Ou Beet                                          0.001329  0.004061
# Eyeshield 21                                            0.007295  0.002832
# Hachimitsu to Clover                                    0.003676  0.001029
# Hungry Heart: Wild Striker                              0.003863  0.000000
# Initial D Fourth Stage                                  0.002586  0.000000
# Monster                                                 0.004328  0.340928
#
# Name                             Witch Hunter Robin  Bouken Ou Beet  \
# Name
# Cowboy Bebop                               0.346858        0.000493
# Cowboy Bebop: Tengoku no Tobira            0.005476        0.001329
# Trigun                                     0.001689        0.004061
# Witch Hunter Robin                         1.000000        0.004817
# Bouken Ou Beet                             0.004817        1.000000
# Eyeshield 21                               0.041666        0.018529
# Hachimitsu to Clover                       0.000000        0.000650
# Hungry Heart: Wild Striker                 0.004882        0.000000
# Initial D Fourth Stage                     0.002529        0.000000
# Monster                                    0.000000        0.003120
#
# Name                             Eyeshield 21  Hachimitsu to Clover  \
# Name
# Cowboy Bebop                         0.005552              0.000000
# Cowboy Bebop: Tengoku no Tobira      0.007295              0.003676
# Trigun                               0.002832              0.001029
# Witch Hunter Robin                   0.041666              0.000000
# Bouken Ou Beet                       0.018529              0.000650
# Eyeshield 21                         1.000000              0.003712
# Hachimitsu to Clover                 0.003712              1.000000
# Hungry Heart: Wild Striker           0.004407              0.000000
# Initial D Fourth Stage               0.005550              0.008814
# Monster                              0.003516              0.000000
#
# Name                             Hungry Heart: Wild Striker  \
# Name
# Cowboy Bebop                                       0.001693
# Cowboy Bebop: Tengoku no Tobira                    0.003863
# Trigun                                             0.000000
# Witch Hunter Robin                                 0.004882
# Bouken Ou Beet                                     0.000000
# Eyeshield 21                                       0.004407
# Hachimitsu to Clover                               0.000000
# Hungry Heart: Wild Striker                         1.000000
# Initial D Fourth Stage                             0.008446
# Monster                                            0.000000
#
# Name                             Initial D Fourth Stage   Monster  ...  \
# Name                                                               ...
# Cowboy Bebop                                   0.000000  0.003103  ...
# Cowboy Bebop: Tengoku no Tobira                0.002586  0.004328  ...
# Trigun                                         0.000000  0.340928  ...
# Witch Hunter Robin                             0.002529  0.000000  ...
# Bouken Ou Beet                                 0.000000  0.003120  ...
# Eyeshield 21                                   0.005550  0.003516  ...
# Hachimitsu to Clover                           0.008814  0.000000  ...
# Hungry Heart: Wild Striker                     0.008446  0.000000  ...
# Initial D Fourth Stage                         1.000000  0.000000  ...
# Monster                                        0.000000  1.000000  ...
#
# Name                             Beauty and the Brawn  4 Week Lovers  \
# Name
# Cowboy Bebop                                 0.000000       0.004529
# Cowboy Bebop: Tengoku no Tobira              0.000000       0.001168
# Trigun                                       0.000000       0.007871
# Witch Hunter Robin                           0.000582       0.000874
# Bouken Ou Beet                               0.000000       0.000944
# Eyeshield 21                                 0.000816       0.009409
# Hachimitsu to Clover                         0.002088       0.005853
# Hungry Heart: Wild Striker                   0.000000       0.002563
# Initial D Fourth Stage                       0.000000       0.001396
# Monster                                      0.000000       0.003459
#
# Name                             Die, Please!  Miru  \
# Name
# Cowboy Bebop                         0.000000   0.0
# Cowboy Bebop: Tengoku no Tobira      0.000000   0.0
# Trigun                               0.002760   0.0
# Witch Hunter Robin                   0.001071   0.0
# Bouken Ou Beet                       0.000000   0.0
# Eyeshield 21                         0.002611   0.0
# Hachimitsu to Clover                 0.000000   0.0
# Hungry Heart: Wild Striker           0.006733   0.0
# Initial D Fourth Stage               0.005251   0.0
# Monster                              0.005485   0.0
#
# Name                             Wo Mengjian ni Mengjian wo  Thailand  Energy  \
# Name
# Cowboy Bebop                                            0.0       0.0     0.0
# Cowboy Bebop: Tengoku no Tobira                         0.0       0.0     0.0
# Trigun                                                  0.0       0.0     0.0
# Witch Hunter Robin                                      0.0       0.0     0.0
# Bouken Ou Beet                                          0.0       0.0     0.0
# Eyeshield 21                                            0.0       0.0     0.0
# Hachimitsu to Clover                                    0.0       0.0     0.0
# Hungry Heart: Wild Striker                              0.0       0.0     0.0
# Initial D Fourth Stage                                  0.0       0.0     0.0
# Monster                                                 0.0       0.0     0.0
#
# Name                             Wu Nao Monu  Bu Xing Si: Yuan Qi  Di Yi Xulie
# Name
# Cowboy Bebop                             0.0                  0.0          0.0
# Cowboy Bebop: Tengoku no Tobira          0.0                  0.0          0.0
# Trigun                                   0.0                  0.0          0.0
# Witch Hunter Robin                       0.0                  0.0          0.0
# Bouken Ou Beet                           0.0                  0.0          0.0
# Eyeshield 21                             0.0                  0.0          0.0
# Hachimitsu to Clover                     0.0                  0.0          0.0
# Hungry Heart: Wild Striker               0.0                  0.0          0.0
# Initial D Fourth Stage                   0.0                  0.0          0.0
# Monster                                  0.0                  0.0          0.0
#
# [10 rows x 18486 columns]

# %%
# anime list 
anime_list = similarity_df.columns.values


# sample anime
anime = 'Death Note'

# top recommendation movie count
top_n = 10

# get anime similarity records
anime_sim = similarity_df[similarity_df.index == anime].values[0]

# get animes sorted by similarity
sorted_anime_ids = np.argsort(anime_sim)[::-1]

# get recommended anime names
recommended_anime = anime_list[sorted_anime_ids[1:top_n+1]]

print('\n\nTop Recommended Anime for:', anime, 'are:-\n', recommended_anime)
# Out:
# Top Recommended Anime for: Death Note are:-
#  ['Death Note: Rewrite' 'Otogi Juushi Akazukin OVA'
#  'Nezumi Monogatari: George to Gerald no Bouken' 'Death Parade'
#  'MapleStory' 'Majin Tantei Nougami Neuro'
#  'Hiroshima ni Ichiban Densha ga Hashitta' 'Kamisama no Inai Nichiyoubi'
#  'Rainbow: Nisha Rokubou no Shichinin'
#  'Hunter x Hunter Movie 2: The Last Mission']

# %%
def content_anime_recommender(
    input_anime, similarity_database=similarity_df, anime_database_list=anime_list, top_n=10):
    
    # get anime similarity records
    anime_sim = similarity_database[similarity_database.index == input_anime].values[0]
    
    # get anime sorted by similarity
    sorted_anime_ids = np.argsort(anime_sim)[::-1]
    
    # get recommended anime names
    recommended_anime = anime_database_list[sorted_anime_ids[1:top_n+1]]
    
    print('\n\nTop Recommended Anime for:', input_anime, 'are:-\n', recommended_anime)

sample_anime = ['Death Note', 'Cowboy Bebop', 'Bleach', 
                 'Fruits Basket', 'Monster']
                 
for i in sample_anime:
    content_anime_recommender(i)
# Out:
# Top Recommended Anime for: Death Note are:-
#  ['Death Note: Rewrite' 'Otogi Juushi Akazukin OVA'
#  'Nezumi Monogatari: George to Gerald no Bouken' 'Death Parade'
#  'MapleStory' 'Majin Tantei Nougami Neuro'
#  'Hiroshima ni Ichiban Densha ga Hashitta' 'Kamisama no Inai Nichiyoubi'
#  'Rainbow: Nisha Rokubou no Shichinin'
#  'Hunter x Hunter Movie 2: The Last Mission']
#
#
# Top Recommended Anime for: Cowboy Bebop are:-
#  ['Cowboy Bebop: Ein no Natsuyasumi' 'Cowboy Bebop: Yose Atsume Blues'
#  'Kidou Shinseiki Gundam X' 'Seihou Bukyou Outlaw Star'
#  'Seihou Tenshi Angel Links' 'Witch Hunter Robin'
#  'Kidou Senshi Gundam II: Ai Senshi-hen' 'Brigadoon: Marin to Melan'
#  'Turn A Gundam' 'Densetsu Kyojin Ideon: Hatsudou-hen']
#
#
# Top Recommended Anime for: Bleach are:-
#  ['Bleach: Sennen Kessen-hen'
#  'Bleach Movie 3: Fade to Black - Kimi no Na wo Yobu'
#  'Bleach Movie 1: Memories of Nobody' 'Bleach Movie 4: Jigoku-hen'
#  'Bleach: The Sealed Sword Frenzy'
#  'Bleach Movie 2: The DiamondDust Rebellion - Mou Hitotsu no Hyourinmaru'
#  'Juuni Kokuki' 'Boruto: Naruto the Movie'
#  'Naruto: Shippuuden Movie 6 - Road to Ninja'
#  'Boruto: Naruto Next Generations']
#
#
# Top Recommended Anime for: Fruits Basket are:-
#  ['Touka Gettan' 'Fruits Basket 1st Season' 'Fruits Basket 2nd Season'
#  'Fruits Basket: The Final' 'Shining Tears X Wind' 'Princess Princess'
#  'Megane-bu!' 'Umineko no Naku Koro ni' 'Sankarea OVA' 'Binchou-tan']
#
#
# Top Recommended Anime for: Monster are:-
#  ['Monster Special Edition' 'Monster Extra: Hottan' '48x61'
#  'Gunslinger Girl' 'Super Doll Licca-chan' 'Hanada Shounen-shi'
#  'Mouryou no Hako' 'Black Jack' 'Metropolis'
#  'Saiunkoku Monogatari 2nd Season']

# %%
df_users_ratings = pd.read_csv('../data/users-score-2023.csv')
df_users_ratings[df_users_ratings['Anime Title'] == 'Death Note'].head()
print(df_users_ratings.shape)
# Out:
# (24325191, 5)

# %% [markdown]
# ### Deriving ground truth using threshold-based approach

# %%
# find relevant anime for ground truth, set ratings above 7
threshold = 7

sample_size = 10000

# take sample from df_users_ratings
sample_data = df_users_ratings.sample(n=sample_size, random_state=42)  #set random_state for reproducibility

#create ground truth based on the threshold
avg_ratings = sample_data.groupby('Anime Title')['rating'].mean()
print(avg_ratings)

# Filter out titles where the average rating is greater than the threshold
liked_anime = avg_ratings[avg_ratings > threshold].index.tolist()

# group by anime and create the ground_truths dictionary
ground_truths = df_users_ratings.groupby('Anime Title')['Anime Title'].apply(lambda x: liked_anime).to_dict()


#print out the items
print (set(ground_truths))
# Out:
# Anime Title
# "Bungaku Shoujo" Kyou no Oyatsu: Hatsukoi     8.000000
# "Bungaku Shoujo" Movie                        7.750000
# "Oshi no Ko"                                  8.500000
# .hack//G.U. Returner                          7.000000
# .hack//G.U. Trilogy: Parody Mode              6.000000
#                                                ...
# xxxHOLiC                                      8.714286
# xxxHOLiC Movie: Manatsu no Yoru no Yume       6.833333
# xxxHOLiC Rou                                 10.000000
# xxxHOLiC Shunmuki                             7.500000
# xxxHOLiC◆Kei                                  7.333333
# Name: rating, Length: 3148, dtype: float64
# {'Kikyuu', 'Fettu to Ccine to Gummi Seijin', 'Rilakkuma to Yuuenchi', 'Val x Love', 'Shigeru', 'Nudist Beach ni Shuugaku Ryokou de!! The Animation', 'Oosouji', 'Onigiri', 'Hua Jianghu: Huan Shi Men Sheng 2nd Season', 'Pokemon Sun & Moon', 'Grappler Baki: Saidai Tournament-hen', 'Hangyakusei Million Arthur PV', "Asura Cryin' 2", 'Accel World EX', 'Cinterrier-jou no Hanamuko', 'Sangenshoku', 'Akashi', 'Kaisou Ressha', 'Cheonnyeon-yeowoo Yeowoobi', 'Kotoura-san: Haruka no Heya', 'Wake Up, Girls! Beyond the Bottom', "Be Rockin'", 'Zoning Tokyo', 'Snobbism', 'Stella-Rium', 'Peter Grill to Kenja no Jikan: Super Extra', 'Take It Easy', 'Hunter x Hunter Movie 1: Phantom Rouge', 'Totsukuni no Shoujo', 'Jigoku Youchien', 'Kishin Douji Zenki', 'Uramichi Oniisan', 'Chuunibyou demo Koi ga Shitai! Kirameki no... Slapstick Noel', 'Love Machine: Animaid Shoufu 23-gou', 'Lagtrain', 'Mudazumo Naki Kaikaku: The Legend of Koizumi', 'Shengsi Huifang', 'Shintaisou: Kari', 'Houkago no Pleiades: Manner Movie', 'Sore Ike! Anpanman', 'Punpun Polka', 'Boku no Marie', 'Shin Grimm Meisaku Gekijou', 'Kimi dake ni Motetainda.', 'Calihara no Uta', 'Legend of Crystania', 'Atom: The Beginning', 'Mob Psycho 100: Reigen - Shirarezaru Kiseki no Reinouryokusha', 'Ukkari Pénélope (2009)', 'Qin Shi Mingyue: Tian Xing Jiu Ge', 'Kedamono-tachi no Sumu Ie de', 'Code:Breaker', 'Scandal', 'Kidou Senshi Gundam 00 Special Edition', 'Psycho-Pass 2', 'Busou Shoujotai: Blade Briders The Animation', "Damen's Walker", 'Kidou Senshi Gundam SEED Special Edition', 'Toshoshitsu no Kanojo: Seiso na Kimi ga Ochiru made - The Animation', 'Subete ga F ni Naru', 'Sugar Bunnies Fleur', 'Junk Head', 'Roshutsu-kei Mahou Joshi Daisei Christhea', 'Hime-sama Love Life!', 'Junjou Romantica OVA', 'Momoko, Kaeru no Uta ga Kikoeru yo.', 'Shounen Sunday CM: Be Blues! Ao ni Nare', 'Sexfriend Gakuen', 'Fate/Zero 2nd Season', 'InaDan Movie x Mameshiba Collab CM', 'Kill Me Baby: Butsuzou Kegatte Nise Halloween', 'Tsukiyomi', 'Norman the Snowman: Kita no Kuni no Aurora', 'Fate/strange Fake PV', 'Koi ni Naritai Aquarium', 'Shen Ji Long Wei', 'Atama Yama', 'Energy Kyouka!!', 'Great Teacher Onizuka Recaps', 'Kinnikuman (Movie)', 'Goro-chan', 'Pokemon: Pichu to Pikachu', 'Shinkalion Hello Kitty', 'Toriko no Kusari: Shojo-tachi wo Yogosu Midara na Kusabi', 'Mononoke', 'DRAMAtical Murder', 'Kero 0: Shuppatsu da yo! Zenin Shuugou!', 'I Just Rock', 'Qing Lian Jian Xian Chuan', 'Isekai de Cheat Skill wo Te ni Shita Ore wa, Genjitsu Sekai wo mo Musou Suru: Level Up wa Jinsei wo Kaeta', 'ViVid Strike!', 'The SoulTaker: Tamashii-gari - Komugi Daisakusen', "Queen's Blade: Unlimited", 'Burn Up Excess', 'A Christmas Song', 'Kero Kero Keroppi no Bokutachi no Takaramono', 'Shinmai Maou no Testament Specials', 'Shelter (Music)', "Shashinki '87", 'Monster Farm 5: Circus Caravan OVA - Kessei!! Orcoro Circus', 'Higurashi no Naku Koro ni Rei', 'Ginga Tetsudou 999: Kimi wa Senshi no You ni Ikirareru ka?', 'Kiss of Life', 'Fujun Isei Kouyuu: Taisetsu na Kimi e', 'Toromitsu Musume no Hitou Service: Torottoro Churu Churu Gohoushi Sasete Kudasai', 'Aa Harimanada', 'Kansen Sodom', 'Kakegurui××', 'Air Gear Special', 'Ao no Kanata no Four Rhythm', 'Keppeki Danshi! Aoyama-kun', 'Gabriel DropOut Specials', 'Juu Ou Sei', 'Gravity (2019)', 'Kawazuno Mekaridoki', 'Shuwarin☆Dorimin', 'Dengeki Oshioki Musume Gootaman R: Ai to Kanashimi no Final Battle', 'Shampoo no Nioi ga Shita', 'Carole & Tuesday Specials', 'Ai W-kun', 'Osomatsu-san Short Film Series 2nd Season', 'Ao no Strada', 'Lu Shidai 2nd Season', 'Oretachi ni Tsubasa wa Nai: Hadairo Ritsu Kyuuwari Zou!?', 'Love² Police', 'Buzzer Beater 2nd Season', 'Adventures in Beauty Wonderland', 'Amaama to Inazuma', 'Starless: 21st Century Nymphomaniacs', 'Ganbare! Kickers Specials', 'Marmalade Boy Movie', 'Kaette Kita Top wo Nerae! Kagaku Kouza', 'Appleseed Alpha', 'Hakumei to Mikochi', 'AIKa: Special Trial', 'Xi Avant', 'Fuyu no Sonata: Joshou - Hatsuyuki no Negai', 'The Impression of First  ...

# %%
#precision at n: measures the proportion of relevant items among the top n
def content_anime_recommender2(
    input_anime, ground_truths, similarity_database=similarity_df, anime_database_list=anime_list, top_n=10):
    
    # get anime similarity records
    anime_sim = similarity_database[similarity_database.index == input_anime].values[0]
    
    # get anime sorted by similarity
    sorted_anime_ids = np.argsort(anime_sim)[::-1]
    
    # get recommended anime names
    recommended_anime = anime_database_list[sorted_anime_ids[1:top_n+1]]
    
    # Calculate Precision at K
    intersection = set(recommended_anime) & set(ground_truths)
    precision_at_n = len(intersection) / top_n
    rounded_precision = round(precision_at_n, 2)
    
    print('\n\nTop Recommended Anime for ', input_anime, recommended_anime)
    print('\nPrecision at', top_n, '=', rounded_precision)

#select 2 highly rated and 2 lower rated titles
sample_anime2 = ['Death Note', 'Jigoku Shoujo Mitsuganae', 'Xian Yu Ge', 'Higenashi Gogejabaru']

for i in sample_anime2:
    content_anime_recommender2(i, ground_truths)
# Out:
# Top Recommended Anime for  Death Note ['Death Note: Rewrite' 'Otogi Juushi Akazukin OVA'
#  'Nezumi Monogatari: George to Gerald no Bouken' 'Death Parade'
#  'MapleStory' 'Majin Tantei Nougami Neuro'
#  'Hiroshima ni Ichiban Densha ga Hashitta' 'Kamisama no Inai Nichiyoubi'
#  'Rainbow: Nisha Rokubou no Shichinin'
#  'Hunter x Hunter Movie 2: The Last Mission']
#
# Precision at 10 = 1.0
#
#
# Top Recommended Anime for  Jigoku Shoujo Mitsuganae ['Muhyo to Rouji no Mahouritsu Soudan Jimusho 2nd Season' 'Tactics'
#  'Muhyo to Rouji no Mahouritsu Soudan Jimusho'
#  'Jigoku Shoujo: Yoi no Togi' 'Jigoku Shoujo' 'Jigoku Shoujo Futakomori'
#  'Jigoku Shoujo Recap' 'Hamelin no Violin Hiki' 'Super Zugan'
#  'Ueki no Housoku']
#
# Precision at 10 = 1.0
#
#
# Top Recommended Anime for  Xian Yu Ge ['Friends: Mononoke Shima no Naki' 'Mao Zhi Ming Episode 5.5'
#  'Chinkoroheibei Tamatebako'
#  'Atelier Petros Joukuu Gekijou: Sentaku Shima no Sentaku Tori'
#  'Minna Tomodachi' 'Seaside-sou no Aquakko'
#  'Qin Shi Mingyue: Xiao Chuangjianghu' 'Nulu-chan to Boku'
#  'Jian Yu Yuanzheng: Insomnia De Naxie Shier' 'Higenashi Gogejabaru']
#
# Precision at 10 = 0.6
#
#
# Top Recommended Anime for  Higenashi Gogejabaru ['Gokuu no Daibouken Pilot' 'Kaijuu no Ballad'
#  'Arifureta Shokugyou de Sekai Saikyou 2nd Season Picture Drama'
#  'Arifureta Shokugyou de Sekai Saikyou Picture Drama'
#  'Sore Ike! Anpanman: Anpanman to Yukai na Nakama-tachi'
#  'Nulu-chan to Boku' "DS Anime Soushuuhen '98" 'Xian Yu Ge'
#  'Eungkka Sonata' 'Xiaobing De Gushi']
#
# Precision at 10 = 0.7
